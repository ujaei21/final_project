# %%
# !apt-get update 
# !apt-get install g++ openjdk-8-jdk python-dev python3-dev 
# !pip3 install JPype1-py3 
# !pip3 install konlpy 
# !JAVA_HOME="C:\Program Files\Java\jdk-16.0.2"
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [717 kB]
# Hit:13 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:15 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [561 kB]
# Hit:17 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,202 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,320 kB]
# Get:20 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,796 kB]
# Get:21 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,428 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,755 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [594 kB]
# Get:24 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [919 kB]
# Fetched 13.6 MB in 6s (2,219 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-dev is already the newest version (2.7.15~rc1-1).
# g++ is already the newest version (4:7.4.0-1ubuntu2.3).
# g++ set to manually installed.
# python3-dev is already the newest version (3.6.7-1~18.04).
# python3-dev set to manually installed.
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libgail-common libgail18 libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libxxf86dga1 openjdk-8-jdk-headless openjdk-8-jre
#   openjdk-8-jre-headless x11-utils
# Suggested packages:
#   gvfs openjdk-8-demo openjdk-8-source visualvm icedtea-8-plugin libnss-mdns
#   fonts-ipafont-gothic fonts-ipafont-mincho fonts-wqy-microhei
#   fonts-wqy-zenhei fonts-indic mesa-utils
# The following NEW packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libgail-common libgail18 libgtk2.0-0 libgtk2.0-bin
#   libgtk2.0-common libxxf86dga1 openjdk-8-jdk openjdk-8-jdk-headless
#   openjdk-8-jre openjdk-8-jre-headless x11-utils
# 0 upgraded, 15 newly installed, 0 to remove and 45 not upgraded.
# Need to get 43.5 MB of archives.
# After this operation, 163 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-core all 2.37-1 [1,041 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-extra all 2.37-1 [1,953 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-utils amd64 7.7+3build1 [196 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk-wrapper-java all 0.33.3-20ubuntu0.1 [34.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk-wrapper-java-jni amd64 0.33.3-20ubuntu0.1 [28.3 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-common all 2.24.32-1ubuntu1 [125 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-0 amd64 2.24.32-1ubuntu1 [1,769 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail18 amd64 2.24.32-1ubuntu1 [14.2 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgail-common amd64 2.24.32-1ubuntu1 [112 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-bin amd64 2.24.32-1ubuntu1 [7,536 B]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jre-headless amd64 8u292-b10-0ubuntu1~18.04 [28.2 MB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jre amd64 8u292-b10-0ubuntu1~18.04 [69.6 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jdk-headless amd64 8u292-b10-0ubuntu1~18.04 [8,284 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jdk amd64 8u292-b10-0ubuntu1~18.04 [1,644 kB]
# Fetched 43.5 MB in 6s (7,554 kB/s)
# Selecting previously unselected package libxxf86dga1:amd64.
# (Reading database ... 148492 files and directories currently installed.)
# Preparing to unpack .../00-libxxf86dga1_2%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.4-1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../01-fonts-dejavu-core_2.37-1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../02-fonts-dejavu-extra_2.37-1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../03-x11-utils_7.7+3build1_amd64.deb ...
# Unpacking x11-utils (7.7+3build1) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../04-libatk-wrapper-java_0.33.3-20ubuntu0.1_all.deb ...
# Unpacking libatk-wrapper-java (0.33.3-20ubuntu0.1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../05-libatk-wrapper-java-jni_0.33.3-20ubuntu0.1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.33.3-20ubuntu0.1) ...
# Selecting previously unselected package libgtk2.0-common.
# Preparing to unpack .../06-libgtk2.0-common_2.24.32-1ubuntu1_all.deb ...
# Unpacking libgtk2.0-common (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgtk2.0-0:amd64.
# Preparing to unpack .../07-libgtk2.0-0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgail18:amd64.
# Preparing to unpack .../08-libgail18_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail18:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgail-common:amd64.
# Preparing to unpack .../09-libgail-common_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libgtk2.0-bin.
# Preparing to unpack .../10-libgtk2.0-bin_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Selecting previously unselected package openjdk-8-jre-headless:amd64.
# Preparing to unpack .../11-openjdk-8-jre-headless_8u292-b10-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-8-jre-headless:amd64 (8u292-b10-0ubuntu1~18.04) ...
# Selecting previously unselected package openjdk-8-jre:amd64.
# Preparing to unpack .../12-openjdk-8-jre_8u292-b10-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-8-jre:amd64 (8u292-b10-0ubuntu1~18.04) ...
# Selecting previously unselected package openjdk-8-jdk-headless:amd64.
# Preparing to unpack .../13-openjdk-8-jdk-headless_8u292-b10-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-8-jdk-headless:amd64 (8u292-b10-0ubuntu1~18.04) ...
# Selecting previously unselected package openjdk-8-jdk:amd64.
# Preparing to unpack .../14-openjdk-8-jdk_8u292-b10-0ubuntu1~18.04_amd64.deb ...
# Unpacking openjdk-8-jdk:amd64 (8u292-b10-0ubuntu1~18.04) ...
# Setting up libgtk2.0-common (2.24.32-1ubuntu1) ...
# Setting up fonts-dejavu-core (2.37-1) ...
# Setting up libxxf86dga1:amd64 (2:1.1.4-1) ...
# Setting up fonts-dejavu-extra (2.37-1) ...
# Setting up openjdk-8-jre-headless:amd64 (8u292-b10-0ubuntu1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/orbd to provide /usr/bin/orbd (orbd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/servertool to provide /usr/bin/servertool (servertool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/tnameserv to provide /usr/bin/tnameserv (tnameserv) in auto mode
# Setting up libgtk2.0-0:amd64 (2.24.32-1ubuntu1) ...
# Setting up libgail18:amd64 (2.24.32-1ubuntu1) ...
# Setting up openjdk-8-jdk-headless:amd64 (8u292-b10-0ubuntu1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/idlj to provide /usr/bin/idlj (idlj) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/wsimport to provide /usr/bin/wsimport (wsimport) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jsadebugd to provide /usr/bin/jsadebugd (jsadebugd) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/native2ascii to provide /usr/bin/native2ascii (native2ascii) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/javah to provide /usr/bin/javah (javah) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/hsdb to provide /usr/bin/hsdb (hsdb) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/clhsdb to provide /usr/bin/clhsdb (clhsdb) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/extcheck to provide /usr/bin/extcheck (extcheck) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/schemagen to provide /usr/bin/schemagen (schemagen) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/xjc to provide /usr/bin/xjc (xjc) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jhat to provide /usr/bin/jhat (jhat) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/wsgen to provide /usr/bin/wsgen (wsgen) in auto mode
# Setting up x11-utils (7.7+3build1) ...
# Setting up libgail-common:amd64 (2.24.32-1ubuntu1) ...
# Setting up libatk-wrapper-java (0.33.3-20ubuntu0.1) ...
# Setting up libgtk2.0-bin (2.24.32-1ubuntu1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.33.3-20ubuntu0.1) ...
# Setting up openjdk-8-jre:amd64 (8u292-b10-0ubuntu1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/policytool to provide /usr/bin/policytool (policytool) in auto mode
# Setting up openjdk-8-jdk:amd64 (8u292-b10-0ubuntu1~18.04) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/appletviewer to provide /usr/bin/appletviewer (appletviewer) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jconsole to provide /usr/bin/jconsole (jconsole) in auto mode
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Collecting JPype1-py3
#   Downloading JPype1-py3-0.5.5.4.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 3.5 MB/s
# Building wheels for collected packages: JPype1-py3
#   Building wheel for JPype1-py3 (setup.py) ... done
#   Created wheel for JPype1-py3: filename=JPype1_py3-0.5.5.4-cp37-cp37m-linux_x86_64.whl size=2682925 sha256=148f552bd0c5754766c3c938ebf087ba9cd49ac4a575cde815cc1cd33ac13eaa
#   Stored in directory: /root/.cache/pip/wheels/e7/d1/09/f55dca0203b0691945bdf0f63d486a0b4d4e5ec4bd78a2502e
# Successfully built JPype1-py3
# Installing collected packages: JPype1-py3
# Successfully installed JPype1-py3-0.5.5.4
# Collecting konlpy
#   Downloading konlpy-0.5.2-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.3 MB/s
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 37.3 MB/s
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting beautifulsoup4==4.6.0
#   Downloading beautifulsoup4-4.6.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.2 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: JPype1, colorama, beautifulsoup4, konlpy
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.3.0 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
import pandas as pd

# %%
path = '/content/drive/MyDrive/Colab Notebooks/final/'
naver_1 = pd.read_csv(path+'NAVER.csv',encoding='cp949')
naver_2 = pd.read_csv(path+'NAVER_FINISH.csv',encoding='cp949')
kakao = pd.read_csv(path+'kakao_total.csv',encoding='cp949')

# %%
naver_2.tail()
# Out:
#         id title  ... score platform
# 1020  1020    AA  ...  9.68   네이버 웹툰
# 1021  1021  사랑in  ...  9.51   네이버 웹툰
# 1022  1022    까뱅  ...  8.83   네이버 웹툰
# 1023  1023   와탕카  ...  9.63   네이버 웹툰
# 1024  1024    타투  ...  9.20   네이버 웹툰
#
# [5 rows x 7 columns]

# %%
naver_1.title.value_counts()
# Out:
# 잉여특공대              1
# 나는 어디에나 있다         1
# 천마는 평범하게 살 수 없다    1
# 2-3승강장             1
# 리턴 투 플레이어          1
#                   ..
# 팔려 온 신부            1
# 겟백                 1
# 최후의 금빛아이           1
# 방탈출                1
# 시월드 판타지            1
# Name: title, Length: 445, dtype: int64

# %%
naver = pd.concat([naver_1,naver_2])

# %%
naver.title.value_counts()
# Out:
# 성경의 역사             2
# 도플갱어의 게임           1
# 국왕과 성기사의 약탈혼       1
# 소녀 해미              1
# 은둔코인               1
#                   ..
# 데빌샷                1
# 미선 임파서블            1
# 꽃만 키우는데 너무강함       1
# 스피릿 핑거스            1
# 2016 학교 다녀오겠습니다    1
# Name: title, Length: 1469, dtype: int64

# %%
naver[naver.title=='성경의 역사']
# Out:
#       id   title  ...  score platform
# 278  278  성경의 역사  ...  9.082   네이버 웹툰
# 1      1  성경의 역사  ...  7.430   네이버 웹툰
#
# [2 rows x 8 columns]

# %%
naver
# Out:
#         id    title  ...  score platform
# 0        0      참교육  ...  9.776   네이버 웹툰
# 1        1     신의 탑  ...  9.499   네이버 웹툰
# 2        2  뷰티풀 군바리  ...  9.660   네이버 웹툰
# 3        3   윈드브레이커  ...  8.795   네이버 웹툰
# 4        4     팔이피플  ...  9.880   네이버 웹툰
# ...    ...      ...  ...    ...      ...
# 1020  1020       AA  ...  9.680   네이버 웹툰
# 1021  1021     사랑in  ...  9.510   네이버 웹툰
# 1022  1022       까뱅  ...  8.830   네이버 웹툰
# 1023  1023      와탕카  ...  9.630   네이버 웹툰
# 1024  1024       타투  ...  9.200   네이버 웹툰
#
# [1470 rows x 8 columns]

# %%
naver.drop_duplicates('title',inplace=True)

# %%
naver[naver.title=='성경의 역사']
# Out:
#       id   title  ...  score platform
# 278  278  성경의 역사  ...  9.082   네이버 웹툰
#
# [1 rows x 8 columns]

# %%
webtoon = pd.concat([kakao,naver])

# %%
webtoon.head()
# Out:
#              title day genre  ...  id author score
# 0     우선 남동생부터 숨기자   월  로판만화  ... NaN    NaN   NaN
# 1  이번 생은 가주가 되겠습니다   월  로판만화  ... NaN    NaN   NaN
# 2         묵향 다크레이디   월  소년만화  ... NaN    NaN   NaN
# 3     튜토리얼이 너무 어렵다   월  소년만화  ... NaN    NaN   NaN
# 4     8클래스 마법사의 회귀   월  소년만화  ... NaN    NaN   NaN
#
# [5 rows x 9 columns]

# %%
webtoon.reset_index(inplace=True,drop=True)

# %%
webtoon.tail()
# Out:
#      title  day      genre  ...      id  author score
# 3168    AA  NaN   스토리, 로맨스  ...  1020.0  선정, 지숙  9.68
# 3169  사랑in  NaN  옴니버스, 로맨스  ...  1021.0     전세훈  9.51
# 3170    까뱅  NaN   에피소드, 개그  ...  1022.0  X-TEAM  8.83
# 3171   와탕카  NaN   에피소드, 개그  ...  1023.0     우주인  9.63
# 3172    타투  NaN  옴니버스, 드라마  ...  1024.0     노지현  9.20
#
# [5 rows x 9 columns]

# %%
webtoon.author.isnull().sum()
# Out:
# 1704

# %%
webtoon.insert(2, 'writer', 0)
webtoon.insert(3, 'illustrator', 1)

# %%
webtoon.head(3)
# Out:
#              title day  writer  ...  id author score
# 0     우선 남동생부터 숨기자   월       0  ... NaN    NaN   NaN
# 1  이번 생은 가주가 되겠습니다   월       0  ... NaN    NaN   NaN
# 2         묵향 다크레이디   월       0  ... NaN    NaN   NaN
#
# [3 rows x 11 columns]

# %%
# 글 작가, 그림 작가 나누기
webtoon.author.fillna('unknown',inplace=True)
webtoon['writer'], webtoon['illustrator'] = zip(*webtoon['author'].apply(lambda x:[x.strip() for x in x.split('/')] if '/' in x else [x, x]))
webtoon.head(3)
# Out:
#              title day   writer  ...  id   author score
# 0     우선 남동생부터 숨기자   월  unknown  ... NaN  unknown   NaN
# 1  이번 생은 가주가 되겠습니다   월  unknown  ... NaN  unknown   NaN
# 2         묵향 다크레이디   월  unknown  ... NaN  unknown   NaN
#
# [3 rows x 11 columns]

# %%
# 정리
webtoon=webtoon[['title','writer','illustrator','genre','story','platform']]

# %%
webtoon.head(3)
# Out:
#              title  ... platform
# 0     우선 남동생부터 숨기자  ...   카카오페이지
# 1  이번 생은 가주가 되겠습니다  ...   카카오페이지
# 2         묵향 다크레이디  ...   카카오페이지
#
# [3 rows x 6 columns]

# %% [markdown]
# ### 전처리

# %%
import re

def hangul(text):
    return re.sub('[^ㄱ-ㅎ|ㅏ-ㅣ|가-힣]', ' ', text)

# %%
web_copy = webtoon.copy()
# web_copy['title'] = web_copy['title'].apply(lambda x:hangul(x))
web_copy['genre'] = web_copy['genre'].apply(lambda x:hangul(x))
web_copy['story'] = web_copy['story'].apply(lambda x:hangul(x))

web_copy['story'] = web_copy['story'].replace(' ','')
web_copy.head(3)
# Out:
#              title  ... platform
# 0     우선 남동생부터 숨기자  ...   카카오페이지
# 1  이번 생은 가주가 되겠습니다  ...   카카오페이지
# 2         묵향 다크레이디  ...   카카오페이지
#
# [3 rows x 6 columns]

# %%
print(webtoon.iloc[0,4])
print(web_copy.iloc[0,4])
# Out:
# 하필이면 19금 다공일수 피폐 만화에 수의 하나뿐인 누나로 빙의하고 말았다! 재수없게도 광공 남주가 끔살시킬 첫 희생자가 누나인 나라니요 . 이렇게 죽기 싫으니 전략을 짜자. 우선, 또라이 공의 시야에서 남동생을 숨기는 거야!
# 하필이면   금 다공일수 피폐 만화에 수의 하나뿐인 누나로 빙의하고 말았다  재수없게도 광공 남주가 끔살시킬 첫 희생자가 누나인 나라니요   이렇게 죽기 싫으니 전략을 짜자  우선  또라이 공의 시야에서 남동생을 숨기는 거야

# %% [markdown]
# ### 불용어제거

# %%
title=webtoon.title.unique()

# %%
temp=webtoon.writer.apply(lambda x: hangul(x))
writer = temp.unique()

# %%
temp = webtoon.illustrator.apply(lambda x: hangul(x))
illustrator = temp.unique()

# %%
title=list(title)
writer = list(writer)
illustrator = list(illustrator)

# %%
with open(path + 'stopwords_korean.txt','r',encoding='utf8') as f:
    stopwords = f.readline()
stopwords = stopwords.split()
print(stopwords[:5])
# Out:
# ['아', '휴', '아이구', '아이쿠', '아이고']

# %%
new_word=['신작','은','는','도','고','이다','고','다','못','게','주인공','레알','작가','조자룡','곽백수','신성록','김소은','이상윤','린펑']
for word in [new_word,title,writer,illustrator]:
    stopwords.extend(word)
print(stopwords)
# Out:
# ['아', '휴', '아이구', '아이쿠', '아이고', '어', '나', '우리', '저희', '따라', '의해', '을', '를', '에', '의', '가', '으로', '로', '에게', '뿐이다', '의거하여', '근거하여', '입각하여', '기준으로', '예하면', '예를', '들면', '예를', '들자면', '저', '소인', '소생', '저희', '지말고', '하지마', '하지마라', '다른', '물론', '또한', '그리고', '비길수', '없다', '해서는', '안된다', '뿐만', '아니라', '만이', '아니다', '만은', '아니다', '막론하고', '관계없이', '그치지', '않다', '그러나', '그런데', '하지만', '든간에', '논하지', '않다', '따지지', '않다', '설사', '비록', '더라도', '아니면', '만', '못하다', '하는', '편이', '낫다', '불문하고', '향하여', '향해서', '향하다', '쪽으로', '틈타', '이용하여', '타다', '오르다', '제외하고', '이', '외에', '이', '밖에', '하여야', '비로소', '한다면', '몰라도', '외에도', '이곳', '여기', '부터', '기점으로', '따라서', '할', '생각이다', '하려고하다', '이리하여', '그리하여', '그렇게', '함으로써', '하지만', '일때', '할때', '앞에서', '중에서', '보는데서', '으로써', '로써', '까지', '해야한다', '일것이다', '반드시', '할줄알다', '할수있다', '할수있어', '임에', '틀림없다', '한다면', '등', '등등', '제', '겨우', '단지', '다만', '할뿐', '딩동', '댕그', '대해서', '대하여', '대하면', '훨씬', '얼마나', '얼마만큼', '얼마큼', '남짓', '여', '얼마간', '약간', '다소', '좀', '조금', '다수', '몇', '얼마', '지만', '하물며', '또한', '그러나', '그렇지만', '하지만', '이외에도', '대해', '말하자면', '뿐이다', '다음에', '반대로', '반대로', '말하자면', '이와', '반대로', '바꾸어서', '말하면', '바꾸어서', '한다면', '만약', '그렇지않으면', '까악', '툭', '딱', '삐걱거리다', '보드득', '비걱거리다', '꽈당', '응당', '해야한다', '에', '가서', '각', '각각', '여러분', '각종', '각자', '제각기', '하도록하다', '와', '과', '그러므로', '그래서', '고로', '한', '까닭에', '하기', '때문에', '거니와', '이지만', '대하여', '관하여', '관한', '과연', '실로', '아니나다를가', '생각한대로', '진짜로', '한적이있다', '하곤하였다', '하', '하하', '허허', '아하', '거바', '와', '오', '왜', '어째서', '무엇때문에', '어찌', '하겠는가', '무슨', '어디', '어느곳', '더군다나', '하물며', '더욱이는', '어느때', '언제', '야', '이봐', '어이', '여보시오', '흐흐', '흥', '휴', '헉헉', '헐떡헐떡', '영차', '여차', '어기여차', '끙끙', '아야', '앗', '아야', '콸콸', '졸졸', '좍좍', '뚝뚝', '주룩주룩', '솨', '우르르', '그래도', '또', '그리고', '바꾸어말하면', '바꾸어말하자면', '혹은', '혹시', '답다', '및', '그에', '따르는', '때가', '되어', '즉', '지든지', '설령', '가령', '하더라도', '할지라도', '일지라도', '지든지', '몇', '거의', '하마터면', '인젠', '이젠', '된바에야', '된이상', '만큼', '어찌됏든', '그위에', '게다가', '점에서', '보아', '비추어', '보아', '고려하면', '하게될것이다', '일것이다', '비교적', '좀', '보다더', '비하면', '시키다', '하게하다', '할만하다', '의해서', '연이서', '이어서', '잇따라', '뒤따라', '뒤이어', '결국', '의지하여', '기대여', '통하여', '자마자', '더욱더', '불구하고', '얼마든지', '마음대로', '주저하지', '않고', '곧', '즉시', '바로', '당장', '하자마자', '밖에', '안된다', '하면된다', '그래', '그렇지', '요컨대', '다시', '말하자면', '바꿔', '말하면', '즉', '구체적으로', '말하자면', '시작하여', '시초에', '이상', '허', '헉', '허걱', '바와같이', '해도좋다', '해도된다', '게다가', '더구나', '하물며', '와르르', '팍', '퍽', '펄렁', '동안', '이래', '하고있었다', '이었다', '에서', '로부터', '까지', '예하면', '했어요', '해요', '함께', '같이', '더불어', '마저', '마저도', '양자', '모두', '습니다', '가까스로', '하려고하다', '즈음하여', '다른', '다른', '방면으로', '해봐요', '습니까', '했어요', '말할것도', '없고', '무릎쓰고', '개의치않고', '하는것만', '못하다', '하는것이', '낫다', '매', '매번', '들', '모', '어느것', '어느', '로써', '갖고말하자면', '어디', '어느쪽', '어느것', '어느해', '어느', '년도', '라', '해도', '언젠가', '어떤것', '어느것', '저기', '저쪽', '저것', '그때', '그럼', '그러면', '요만한걸', '그래', '그때', '저것만큼', '그저', '이르기까지', '할', '줄', '안다', '할', '힘이', '있다', '너', '너희', '당신', '어찌', '설마', '차라리', '할지언정', '할지라도', '할망정', '할지언정', '구토하다', '게우다', '토하다', '메쓰겁다', '옆사람', '퉤', '쳇', '의거하여', '근거하여', '의해', '따라', '힘입어', '그', '다음', '버금', '두번째로', '기타', '첫번째로', '나머지는', '그중에서', '견지에서', '형식으로', '쓰여', '입장에서', '위해서', '단지', '의해되다', '하도록시키다', '뿐만아니라', '반대로', '전후', '전자', '앞의것', '잠시', '잠깐', '하면서', '그렇지만', '다음에', '그러한즉', '그런즉', '남들', '아무거나', '어찌하든지', '같다', '비슷하다', '예컨대', '이럴정도로', '어떻게', '만약', '만일', '위에서', '서술한바와같이', '인', '듯하다', '하지', '않는다면', '만약에', '무엇', '무슨', '어느', '어떤', '아래윗', '조차', '한데', '그럼에도', '불구하고', '여전히', '심지어', '까지도', '조차도', '하지', '않도록', '않기', '위하여', '때', '시각', '무렵', '시간', '동안', '어때', '어떠한', '하여금', '네', '예', '우선', '누구', '누가', '알겠는가', '아무도', '줄은모른다', '줄은', '몰랏다', '하는', '김에', '겸사겸사', '하는바', '그런', '까닭에', '한', '이유는', '그러니', '그러니까', '때문에', '그', '너희', '그들', '너희들', '타인', '것', '것들', '너', '위하여', '공동으로', '동시에', '하기', '위하여', '어찌하여', '무엇때문에', '붕붕', '윙윙', '나', '우리', '엉엉', '휘익', '윙윙', '오호', '아하', '어쨋든', '만', '못하다', '하기보다는', '차라리', '하는', '편이', '낫다', '흐흐', '놀라다', '상대적으로', '말하자면', '마치', '아니라면', '쉿', '그렇지', '않으면', '그렇지', '않다면', '안', '그러면', '아니었다면', '하든지', '아니면', '이라면', '좋아', '알았어', '하는것도', '그만이다', '어쩔수', '없다', '하나', '일', '일반적으로', '일단', '한켠으로는', '오자마자', '이렇게되면', '이와같다면', '전부', '한마 ...

# %% [markdown]
# ### 토큰화

# %%
from konlpy.tag import Okt, Hannanum, Kkma, Komoran, Mecab
okt = Okt() # Okt : Open Korean Text
hannanum = Hannanum() # Hannanum(한나눔) : KAIST
kkma = Kkma() # Kkma(꼬꼬마) : 서울대학교
komoran = Komoran() # Komoran : Shineware

def okt_tokenizer(text):
    # 입력 인자로 들어온 텍스트를 형태소 단어로 토큰화해 리스트 형태로 반환
    tokens_ko = okt.morphs(text)
    filtered_words = []
    # 각 문장별 단어에 대해 스톱 워드 제거
    for word in tokens_ko:
        if word not in stopwords:
            filtered_words.append(word)
    
    return filtered_words

def kkma_tokenizer(text):
    # 입력 인자로 들어온 텍스트를 형태소 단어로 토큰화해 리스트 형태로 반환
    tokens_ko = kkma.morphs(text)
    filtered_words = []
    # 각 문장별 단어에 대해 스톱 워드 제거
    for word in tokens_ko:
        if word not in stopwords:
            filtered_words.append(word)
    
    return filtered_words

def hannanum_tokenizer(text):
    # 입력 인자로 들어온 텍스트를 형태소 단어로 토큰화해 리스트 형태로 반환
    tokens_ko = hannanum.morphs(text)
    filtered_words = []
    # 각 문장별 단어에 대해 스톱 워드 제거
    for word in tokens_ko:
        if word not in stopwords:
            filtered_words.append(word)
    
    return filtered_words

def komoran_tokenizer(text):
    # 입력 인자로 들어온 텍스트를 형태소 단어로 토큰화해 리스트 형태로 반환
    tokens_ko = komoran.morphs(text)
    filtered_words = []
    # 각 문장별 단어에 대해 스톱 워드 제거
    for word in tokens_ko:
        if word not in stopwords:
            filtered_words.append(word)
    
    return filtered_words

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack
from sklearn.preprocessing import LabelBinarizer

# 입력 값 : 토큰화 도구, 작가도 feature에 포함할지 여부, 제목도 feature에 포함할지 여부
def get_sparse_matrix(tokenizer, author=True, title=True):
    # 제목, 장르 벡터화
    tfidf_nstory_vec = TfidfVectorizer(tokenizer=tokenizer)
    tfidf_title_matrix = tfidf_nstory_vec.fit_transform(web_copy['title'])
    tfidf_genre_matrix = tfidf_nstory_vec.fit_transform(web_copy['genre'])

    # 작가 인코딩
    if author:
        lb = LabelBinarizer(sparse_output=True) # 다른 행렬과 합치기 위하여 희소 행렬로 반환
        lb_writer_matrix = lb.fit_transform(web_copy['writer'])
        lb_illustrator_matrix = lb.fit_transform(web_copy['illustrator'])
    
    # 줄거리 벡터화
    tfidf_story_vec = TfidfVectorizer(tokenizer=tokenizer, ngram_range=(1, 3))
    tfidf_story_matrix = tfidf_story_vec.fit_transform(web_copy['story'])
    
    # 만들어진 행렬을 합치기 위한 리스트
    sparse_matrix_list = [tfidf_genre_matrix, tfidf_story_matrix]
    if author:
        sparse_matrix_list.append(lb_writer_matrix)
        sparse_matrix_list.append(lb_illustrator_matrix)
    
    if title:
        sparse_matrix_list.append(tfidf_title_matrix)
    
    sparse_matrix_list = tuple(sparse_matrix_list)

    # 행렬 결합
    X_features_sparse = hstack(sparse_matrix_list).tocsr()
    print(type(X_features_sparse), X_features_sparse.shape)
    
    return X_features_sparse

# %%
web_copy.story[0]
# Out:
# '하필이면   금 다공일수 피폐 만화에 수의 하나뿐인 누나로 빙의하고 말았다  재수없게도 광공 남주가 끔살시킬 첫 희생자가 누나인 나라니요   이렇게 죽기 싫으니 전략을 짜자  우선  또라이 공의 시야에서 남동생을 숨기는 거야 '

# %%
# %%time

tokenizers = [okt_tokenizer, kkma_tokenizer, hannanum_tokenizer, komoran_tokenizer]

# 작가, 제목 포함 행렬
all_contain_matrices = [get_sparse_matrix(tokenizer) for tokenizer in tokenizers]

# 제목 포함, 작가 미포함 행렬
title_contain_matrices = [get_sparse_matrix(tokenizer, author=False) for tokenizer in tokenizers]

# 작가 포함, 제목 미포함 행렬
author_contain_matrices = [get_sparse_matrix(tokenizer, title=False) for tokenizer in tokenizers]

# 작가, 제목 미포함 행렬
notall_contain_matrices = [get_sparse_matrix(tokenizer, title=False, author=False) for tokenizer in tokenizers]
# Out:
# <class 'scipy.sparse.csr.csr_matrix'> (3173, 238127)
# <class 'scipy.sparse.csr.csr_matrix'> (3173, 233029)
# <class 'scipy.sparse.csr.csr_matrix'> (3173, 222470)
# <class 'scipy.sparse.csr.csr_matrix'> (3173, 225801)
# <class 'scipy.sparse.csr.csr_matrix'> (3173, 236190)
# <class 'scipy.sparse.csr.csr_matrix'> (3173, 231092)
# <class 'scipy.sparse.csr.csr_matrix'> (3173, 220533)
# <class 'scipy.sparse.csr.csr_matrix'> (3173, 223864)
# <class 'scipy.sparse.csr.csr_matrix'> (3173, 234363)
# <class 'scipy.sparse.csr.csr_matrix'> (3173, 229595)
# <class 'scipy.sparse.csr.csr_matrix'> (3173, 219406)
# <class 'scipy.sparse.csr.csr_matrix'> (3173, 222572)
# <class 'scipy.sparse.csr.csr_matrix'> (3173, 232426)
# <class 'scipy.sparse.csr.csr_matrix'> (3173, 227658)
# <class 'scipy.sparse.csr.csr_matrix'> (3173, 217469)
# <class 'scipy.sparse.csr.csr_matrix'> (3173, 220635)
# CPU times: user 1h 14min 11s, sys: 30 s, total: 1h 14min 41s
# Wall time: 41min 20s

# %%
indices = pd.Series(webtoon.index, index=webtoon['title'])
indices.head(3)
# Out:
# title
# 우선 남동생부터 숨기자       0
# 이번 생은 가주가 되겠습니다    1
# 묵향 다크레이디           2
# dtype: int64

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# 입력 값 : 제목, top rank 수, 같은 장르만 뽑을지 여부, 작가를 feature로 넣을지 여부, 제목을 feature로 넣을 지 여부
def get_recomm(title, rank=10, same_genre=False, author=True, _title=True):
    # 코사인 유사도를 담을 array 생성
    cosine_sim = np.zeros((len(webtoon), len(webtoon)))
    
    if author and _title:
        matrices = all_contain_matrices
    elif author:
        matrices = author_contain_matrices
    elif _title:
        matrices = title_contain_matrices
    else:
        matrices = notall_contain_matrices
    
    # 코사인 유사도 계산
    # 각 토큰화 도구로 계산한 코사인 유사도를 평균 (앙상블)
    for matrix in matrices:
        cosine_sim += cosine_similarity(matrix)
    cosine_sim /= len(matrices)
    
    # 결과 출력을 위한 데이터 프레임 복사
    print_copy = webtoon.copy()
    
    # 선택한 웹툰 제목으로부터 해당되는 인덱스를 받아옴
    idx = indices[title]
    
    # 인덱스로부터 장르를 뽑아옴
    genre = print_copy.loc[idx, 'genre']

    # 유사도를 DataFrame에 붙임
    print_copy['similarity'] = cosine_sim[idx]
    
    if same_genre:
        # 동일 장르만을 보여줄 경우
        return print_copy[print_copy['genre'] == genre].sort_values(by='similarity', ascending=False).iloc[1:1+rank, :]
        
    else:
        # 다른 장르도 보여줄 경우
        return print_copy.sort_values(by='similarity', ascending=False).iloc[1:1+rank, :]

# %%
get_recomm('비흔')
# Out:
#              title writer  ... platform similarity
# 3160            제로    정재한  ...   네이버 웹툰   0.283190
# 2803          후레자식    김칸비  ...   네이버 웹툰   0.257256
# 2464  [드라마원작] 스위트홈    김칸비  ...   네이버 웹툰   0.243018
# 2995          그린보이    정재한  ...   네이버 웹툰   0.240421
# 1877           칼부림    고일권  ...   네이버 웹툰   0.237160
# 2634            혈투    신진우  ...   네이버 웹툰   0.236803
# 2536            귀인    정연식  ...   네이버 웹툰   0.236803
# 3085            묵회     한나  ...   네이버 웹툰   0.230205
# 2007            몽홀    장태산  ...   네이버 웹툰   0.224488
# 3159         태왕광개토    청안랑  ...   네이버 웹툰   0.222137
#
# [10 rows x 7 columns]

# %%
get_recomm('비흔',author=False)
# Out:
#        title   writer  ... platform similarity
# 1877     칼부림      고일권  ...   네이버 웹툰   0.454817
# 2634      혈투      신진우  ...   네이버 웹툰   0.454124
# 2536      귀인      정연식  ...   네이버 웹툰   0.454124
# 3085      묵회       한나  ...   네이버 웹툰   0.431186
# 2007      몽홀      장태산  ...   네이버 웹툰   0.412781
# 3159   태왕광개토      청안랑  ...   네이버 웹툰   0.400494
# 2467  조선방랑야사       가현  ...   네이버 웹툰   0.396970
# 1842    화산귀환       비가  ...   네이버 웹툰   0.395112
# 3029    한섬세대      유승진  ...   네이버 웹툰   0.394439
# 2336  봉이 김선달  양우석,정하용  ...   네이버 웹툰   0.394237
#
# [10 rows x 7 columns]

# %%
get_recomm('비흔',author=False,_title=False)
# Out:
#             title writer  ... platform similarity
# 3159        태왕광개토    청안랑  ...   네이버 웹툰   0.508504
# 2980        삵의 발톱    손영완  ...   네이버 웹툰   0.507756
# 2720    천국의 신화 6부  올댓스토리  ...   네이버 웹툰   0.505223
# 3091        흐드러지다    연제원  ...   네이버 웹툰   0.504650
# 2467       조선방랑야사     가현  ...   네이버 웹툰   0.503945
# 2881           문아     팬마  ...   네이버 웹툰   0.502008
# 1842         화산귀환     비가  ...   네이버 웹툰   0.501691
# 2604       왕으로 살다   네스티캣  ...   네이버 웹툰   0.501223
# 3029         한섬세대    유승진  ...   네이버 웹툰   0.500952
# 2841  아이소포스 1, 2부    김양수  ...   네이버 웹툰   0.500857
#
# [10 rows x 7 columns]

# %%
get_recomm('프리드로우')
# Out:
#         title writer  ... platform similarity
# 1894       구주     준치  ...   네이버 웹툰   0.244027
# 2196    오늘또오늘    희나리  ...   네이버 웹툰   0.243967
# 3160       제로    정재한  ...   네이버 웹툰   0.243935
# 1734      장난감    배사과  ...   네이버 웹툰   0.243912
# 2020   구주의 시간    송극장  ...   네이버 웹툰   0.243847
# 1806      올가미    해무리  ...   네이버 웹툰   0.243834
# 3050     유토피아    늑대삼  ...   네이버 웹툰   0.243791
# 2224       피플    서승준  ...   네이버 웹툰   0.243754
# 2248       상연   YooN  ...   네이버 웹툰   0.243752
# 2304  아이고 아이고     하모  ...   네이버 웹툰   0.243677
#
# [10 rows x 7 columns]

# %%
get_recomm('프리드로우',author=False)
# Out:
#         title writer  ... platform similarity
# 1894       구주     준치  ...   네이버 웹툰   0.478231
# 2196    오늘또오늘    희나리  ...   네이버 웹툰   0.478118
# 3160       제로    정재한  ...   네이버 웹툰   0.478057
# 1734      장난감    배사과  ...   네이버 웹툰   0.478022
# 2020   구주의 시간    송극장  ...   네이버 웹툰   0.477918
# 1806      올가미    해무리  ...   네이버 웹툰   0.477879
# 3050     유토피아    늑대삼  ...   네이버 웹툰   0.477792
# 2224       피플    서승준  ...   네이버 웹툰   0.477721
# 2248       상연   YooN  ...   네이버 웹툰   0.477709
# 2304  아이고 아이고     하모  ...   네이버 웹툰   0.477572
#
# [10 rows x 7 columns]

# %%
get_recomm('프리드로우',author=False,_title=False)
# Out:
#                 title writer  ... platform similarity
# 2194          자취방 신선들     마로  ...   네이버 웹툰   0.523436
# 2818          2호선 세입자    정은경  ...   네이버 웹툰   0.516811
# 2310          우리는 여기!    달꼬냑  ...   네이버 웹툰   0.513430
# 2306         이것도 친구라고     제야  ...   네이버 웹툰   0.512610
# 2296             지랄발광    김인호  ...   네이버 웹툰   0.511486
# 2820           화이트멜로우    임진국  ...   네이버 웹툰   0.510126
# 1952          온실 속 화초    옛사람  ...   네이버 웹툰   0.509292
# 2252          여름은 뜨겁다     JQ  ...   네이버 웹툰   0.509222
# 2928  기적! 우리에게 일어난 일들     태발  ...   네이버 웹툰   0.509045
# 2852             일등당첨     미티  ...   네이버 웹툰   0.508995
#
# [10 rows x 7 columns]

# %%
get_recomm('개장수')
# Out:
#               title writer  ... platform similarity
# 1966            데드퀸    김규삼  ...   네이버 웹툰   0.699972
# 2649          하이브 3    김규삼  ...   네이버 웹툰   0.696782
# 2822        하이브 1~2    김규삼  ...   네이버 웹툰   0.658142
# 2913       버프소녀 오오라    김규삼  ...   네이버 웹툰   0.496262
# 2679      쌉니다 천리마마트    김규삼  ...   네이버 웹툰   0.496219
# 3141      N의등대-눈의등대    김규삼  ...   네이버 웹툰   0.485214
# 3098  입시명문사립 정글고등학교    김규삼  ...   네이버 웹툰   0.448685
# 2773       만렙소녀 오오라    김규삼  ...   네이버 웹툰   0.435553
# 2576       천리마 네버다이    김규삼  ...   네이버 웹툰   0.435524
# 2307           비질란테    CRG  ...   네이버 웹툰   0.280753
#
# [10 rows x 7 columns]

# %%
get_recomm('개장수',author=False)
# Out:
#      title writer  ... platform similarity
# 2188    마도     이밤  ...   네이버 웹툰   0.482421
# 2016   트럼프    이채은  ...   네이버 웹툰   0.481463
# 3083    테제     하람  ...   네이버 웹툰   0.479563
# 2374   오컬트    신진우  ...   네이버 웹툰   0.478757
# 1893    천도     진작  ...   네이버 웹툰   0.478742
# 2692    기로     구들  ...   네이버 웹툰   0.478100
# 2294  블루투스    국승원  ...   네이버 웹툰   0.477470
# 2854    신령     이혜  ...   네이버 웹툰   0.477467
# 2608    알파     부겸  ...   네이버 웹툰   0.477448
# 2234    혼신    임리나  ...   네이버 웹툰   0.477326
#
# [10 rows x 7 columns]

# %%
get_recomm('개장수',author=False,_title=False)
# Out:
#               title  writer  ... platform similarity
# 2649          하이브 3     김규삼  ...   네이버 웹툰   0.600972
# 1966            데드퀸     김규삼  ...   네이버 웹툰   0.520227
# 2246           스테어스      옹구  ...   네이버 웹툰   0.518638
# 2640           노블레스     손제호  ...   네이버 웹툰   0.512287
# 2822        하이브 1~2     김규삼  ...   네이버 웹툰   0.511643
# 2042          어글리후드      미애  ...   네이버 웹툰   0.509878
# 2938  판타지스케치 - 더 게임     엄재경  ...   네이버 웹툰   0.509586
# 1728      리턴 투 플레이어  인덱스,엄키  ...   네이버 웹툰   0.509104
# 1816            오파츠      성진  ...   네이버 웹툰   0.508824
# 2028          호랑이형님     이상규  ...   네이버 웹툰   0.508793
#
# [10 rows x 7 columns]

# %%
get_recomm('마음의소리')
# Out:
#             title writer  ... platform similarity
# 2861       조석축구만화     조석  ...   네이버 웹툰   0.528936
# 2298           후기     조석  ...   네이버 웹툰   0.473607
# 2728           문유     조석  ...   네이버 웹툰   0.455073
# 3035   자율공상축구탐구만화     조석  ...   네이버 웹툰   0.451721
# 2603        조의 영역     조석  ...   네이버 웹툰   0.450209
# 2166         행성인간     조석  ...   네이버 웹툰   0.435410
# 3148  N의등대-busted     조석  ...   네이버 웹툰   0.426408
# 1904    묵시의 인플루언서     조석  ...   네이버 웹툰   0.424473
# 3158        취업의소리  조석,워니  ...   네이버 웹툰   0.253502
# 2641          열대어    실버벨  ...   네이버 웹툰   0.236803
#
# [10 rows x 7 columns]

# %%
get_recomm('마음의소리',author=False)
# Out:
#          title writer  ... platform similarity
# 2641       열대어    실버벨  ...   네이버 웹툰   0.454124
# 3158     취업의소리  조석,워니  ...   네이버 웹툰   0.440288
# 3162      식스센스  릴레이연재  ...   네이버 웹툰   0.438901
# 3161      트라우마    곽백수  ...   네이버 웹툰   0.436862
# 3006      스쿨홀릭    신의철  ...   네이버 웹툰   0.435395
# 2918  역전! 야매요리    정다정  ...   네이버 웹툰   0.416939
# 2650    조선왕조실톡   무적핑크  ...   네이버 웹툰   0.414746
# 2934    실질객관영화   무적핑크  ...   네이버 웹툰   0.412633
# 1854      나쁜사람     둠스  ...   네이버 웹툰   0.412457
# 2958    내일은 웹툰    신의철  ...   네이버 웹툰   0.406848
#
# [10 rows x 7 columns]

# %%
get_recomm('마음의소리',author=False,_title=False)
# Out:
#           title writer  ... platform similarity
# 2958     내일은 웹툰    신의철  ...   네이버 웹툰   0.516544
# 3162       식스센스  릴레이연재  ...   네이버 웹툰   0.508960
# 2655      만 화 고     김8  ...   네이버 웹툰   0.508166
# 1833       피로만땅     샤니  ...   네이버 웹툰   0.506337
# 2932    와라! 편의점    지강민  ...   네이버 웹툰   0.505441
# 2773   만렙소녀 오오라    김규삼  ...   네이버 웹툰   0.505157
# 1726   오늘의 순정망화    손하기  ...   네이버 웹툰   0.503502
# 2650     조선왕조실톡   무적핑크  ...   네이버 웹툰   0.502724
# 2476  203호 저승사자     샤니  ...   네이버 웹툰   0.502012
# 3161       트라우마    곽백수  ...   네이버 웹툰   0.501508
#
# [10 rows x 7 columns]

# %%
get_recomm('패션왕')
# Out:
#       title writer  ... platform similarity
# 2170    복학왕   기안84  ...   네이버 웹툰   0.708944
# 2357     회춘   기안84  ...   네이버 웹툰   0.591614
# 3050   유토피아    늑대삼  ...   네이버 웹툰   0.252397
# 2224     피플    서승준  ...   네이버 웹툰   0.247425
# 2902     미결    꼬마비  ...   네이버 웹툰   0.247033
# 2196  오늘또오늘    희나리  ...   네이버 웹툰   0.243402
# 1734    장난감    배사과  ...   네이버 웹툰   0.243402
# 2582     소유   한(恨)  ...   네이버 웹툰   0.243402
# 2512    수평선    정지훈  ...   네이버 웹툰   0.243402
# 2595   클로즈업    현재권  ...   네이버 웹툰   0.243402
#
# [10 rows x 7 columns]

# %%
get_recomm('패션왕',author=False)
# Out:
#        title writer  ... platform similarity
# 3050    유토피아    늑대삼  ...   네이버 웹툰   0.494667
# 2224      피플    서승준  ...   네이버 웹툰   0.484933
# 2902      미결    꼬마비  ...   네이버 웹툰   0.484174
# 2196   오늘또오늘    희나리  ...   네이버 웹툰   0.477062
# 1734     장난감    배사과  ...   네이버 웹툰   0.477062
# 3129   새끼손가락    이익수  ...   네이버 웹툰   0.477062
# 2248      상연   YooN  ...   네이버 웹툰   0.477062
# 1739  하루의 하루    김이랑  ...   네이버 웹툰   0.477062
# 2595    클로즈업    현재권  ...   네이버 웹툰   0.477062
# 1806     올가미    해무리  ...   네이버 웹툰   0.477062
#
# [10 rows x 7 columns]

# %%
get_recomm('패션왕',author=False,_title=False)
# Out:
#                title   writer  ... platform similarity
# 3070  다욤이의 다이어트 다이어리  아키, 심윤수  ...   네이버 웹툰   0.518652
# 3050            유토피아      늑대삼  ...   네이버 웹툰   0.518514
# 2950            소나기야       와루  ...   네이버 웹툰   0.513911
# 2998            무한동력      주호민  ...   네이버 웹툰   0.512665
# 2160          무의식의 숲      루시드  ...   네이버 웹툰   0.512101
# 3118  17살, 그 여름날의 기적       석우  ...   네이버 웹툰   0.511749
# 2930        아이들은 즐겁다     허5파6  ...   네이버 웹툰   0.510958
# 3002            꽃밭에솔      209  ...   네이버 웹툰   0.510751
# 2270      하루달콤 하루쌉싸름       은유  ...   네이버 웹툰   0.510741
# 2853             Ho!      억수씨  ...   네이버 웹툰   0.510585
#
# [10 rows x 7 columns]

# %%
get_recomm('복학왕')
# Out:
#       title writer  ... platform similarity
# 2992    패션왕   기안84  ...   네이버 웹툰   0.708944
# 2357     회춘   기안84  ...   네이버 웹툰   0.570269
# 1894     구주     준치  ...   네이버 웹툰   0.242105
# 2248     상연   YooN  ...   네이버 웹툰   0.237756
# 2196  오늘또오늘    희나리  ...   네이버 웹툰   0.237185
# 3160     제로    정재한  ...   네이버 웹툰   0.237155
# 1734    장난감    배사과  ...   네이버 웹툰   0.237099
# 3050   유토피아    늑대삼  ...   네이버 웹툰   0.237081
# 2224     피플    서승준  ...   네이버 웹툰   0.237053
# 1806    올가미    해무리  ...   네이버 웹툰   0.237022
#
# [10 rows x 7 columns]

# %%
get_recomm('복학왕',author=False)
# Out:
#        title writer  ... platform similarity
# 1894      구주     준치  ...   네이버 웹툰   0.464329
# 2992     패션왕   기안84  ...   네이버 웹툰   0.462460
# 2248      상연   YooN  ...   네이버 웹툰   0.455953
# 2196   오늘또오늘    희나리  ...   네이버 웹툰   0.454857
# 3160      제로    정재한  ...   네이버 웹툰   0.454799
# 1734     장난감    배사과  ...   네이버 웹툰   0.454691
# 3050    유토피아    늑대삼  ...   네이버 웹툰   0.454659
# 2224      피플    서승준  ...   네이버 웹툰   0.454605
# 1806     올가미    해무리  ...   네이버 웹툰   0.454543
# 2020  구주의 시간    송극장  ...   네이버 웹툰   0.454486
#
# [10 rows x 7 columns]

# %%
get_recomm('복학왕',author=False,_title=False)
# Out:
#                   title writer  ... platform similarity
# 3151            3단합체김창남    하일권  ...   네이버 웹툰   0.532085
# 1982             성경의 역사    최경민  ...   네이버 웹툰   0.530263
# 2808  국립자유경제고등학교 세실고...    양혜석  ...   네이버 웹툰   0.520169
# 2361         결백한 사람은 없다     서각  ...   네이버 웹툰   0.518743
# 2622       찬란하지 않아도 괜찮아    까마중  ...   네이버 웹툰   0.516272
# 2283              셧업앤댄스    이은재  ...   네이버 웹툰   0.514959
# 1834          찐:종합게임동아리     소장  ...   네이버 웹툰   0.513423
# 1894                 구주     준치  ...   네이버 웹툰   0.511144
# 1799               교환학생   올챙구리  ...   네이버 웹툰   0.507920
# 2814      동네변호사 조들호 시즌1    해츨링  ...   네이버 웹툰   0.507360
#
# [10 rows x 7 columns]
