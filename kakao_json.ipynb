# %%
import json

with open('weekdays.json', 'r', encoding='utf8') as f:
    contents = f.read()
    json_data = json.loads(contents)

print(json.dumps(json_data, indent="\t", ensure_ascii=False))
# print(json_data['data']['sections'][0]['cardGroups'][0]['cards'][0]['content']['title'])
# Out:
# {
# 	"data": {
# 		"title": "general-weekdays",
# 		"sections": [
# 			{
# 				"id": "5ff355a6d5d81e6df5bd84bb",
# 				"title": "월",
# 				"module": "WEEKDAYS",
# 				"placement": "channel_mon",
# 				"tag": "weekdays",
# 				"cardGroups": [
# 					{
# 						"cards": [
# 							{
# 								"id": "60e413645c967c09c5ad2438",
# 								"key": "612d8bc048fc245bde93761a-60e413645c967c09c5ad2438",
# 								"content": {
# 									"lookThroughImages": [
# 										"https://kr-a.kakaopagecdn.com/P/C/1781/lt/2x/3b5f323c-d1cc-4c8c-b063-5afde753018e_000",
# 										"https://kr-a.kakaopagecdn.com/P/C/1781/lt/2x/3b5f323c-d1cc-4c8c-b063-5afde753018e_001",
# 										"https://kr-a.kakaopagecdn.com/P/C/1781/lt/2x/3b5f323c-d1cc-4c8c-b063-5afde753018e_002",
# 										"https://kr-a.kakaopagecdn.com/P/C/1781/lt/2x/3b5f323c-d1cc-4c8c-b063-5afde753018e_003",
# 										"https://kr-a.kakaopagecdn.com/P/C/1781/lt/2x/3b5f323c-d1cc-4c8c-b063-5afde753018e_004",
# 										"https://kr-a.kakaopagecdn.com/P/C/1781/lt/2x/3b5f323c-d1cc-4c8c-b063-5afde753018e_005",
# 										"https://kr-a.kakaopagecdn.com/P/C/1781/lt/2x/3b5f323c-d1cc-4c8c-b063-5afde753018e_006",
# 										"https://kr-a.kakaopagecdn.com/P/C/1781/lt/2x/3b5f323c-d1cc-4c8c-b063-5afde753018e_007",
# 										"https://kr-a.kakaopagecdn.com/P/C/1781/lt/2x/3b5f323c-d1cc-4c8c-b063-5afde753018e_008",
# 										"https://kr-a.kakaopagecdn.com/P/C/1781/lt/2x/3b5f323c-d1cc-4c8c-b063-5afde753018e_009"
# 									],
# 									"catchphraseTwoLines": "흑역사 첫 연애 후 남자들이 꼬인다!\n누가 똥차고 누가 벤츠일까?",
# 									"backgroundImage": "https://kr-a.kakaopagecdn.com/P/C/1781/bg/2x/3b5f323c-d1cc-4c8c-b063-5afde753018e",
# 									"channel": "one",
# 									"completedDateTime": null,
# 									"title": "바니와 오빠들",
# 									"titleImageAHeight": 128,
# 									"seoKeywords": [
# 										"#발랄한",
# 										"#설레는",
# 										"#로맨스",
# 										"#로맨틱코미디물"
# 									],
# 									"anchorClip": {
# 										"type": "LOOP",
# 										"clipUrl": "https://kr-a.kakaopagecdn.com/P/C/1781/aclip/2aa947a2-31ed-466a-87b3-b4acee409b9f",
# 										"clipFirstFrame": "https://kr-a.kakaopagecdn.com/P/C/1781/aclip/2x/2aa947a2-31ed-466a-87b3-b4acee409b9f_f~os",
# 										"clipLastFrame": "https://kr-a.kakaopagecdn.com/P/C/1781/aclip/2x/2aa947a2-31ed-466a-87b3-b4acee409b9f_f~os"
# 									},
# 									"ageLimit": 0,
# 									"ipPromotionVideo": {
# 										"title": "바니와 오빠들",
# 										"subtitle": "첫 연애 후 자꾸만 꼬이는 남자들",
# 										"verticalVideo": "https://kr-a.kakaopagecdn.com/P/C/1781/ip1/396d971b-4189-4f67-bafe-a76b4b6c6391",
# 										"horizontalVideo": "https://kr-a.kakaopagecdn.com/P/C/1781/ip2/93720212-610e-4068-8a64-7a524de2474d"
# 									},
# 									"newContent": false,
# 									"serialRestartDateTime": "2021-08-01T15:00:00Z",
# 									"featuredCharacterImageA": "https://kr-a.kakaopagecdn.com/P/C/1781/c1/2x/3b5f323c-d1cc-4c8c-b063-5afde753018e",
# 									"serialStartDateTime": "2019-09-22T00:00:00Z",
# 									"id": 1781,
# 									"featuredCharacterAnimationLastFrame": "https://kr-a.kakaopagecdn.com/P/C/1781/c1a/2x/3b5f323c-d1cc-4c8c-b063-5afde753018e_l~os",
# 									"featuredCharacterImageB": "https://kr-a.kakaopagecdn.com/P/C/1781/c2/2x/51701624-4b03-405c-9db0-5a1be66409c0",
# 									"seoId": "바니와-오빠들",
# 									"rest": false,
# 									"backgroundColor": "#6a3c59",
# 									"upContent": true,
# 									"titleImageA": "https://kr-a.kakaopagecdn.com/P/C/1781/t1/2x/3b5f323c-d1cc-4c8c-b063-5afde753018e",
# 									"titleImageB": "https://kr-a.kakaopagecdn.com/P/C/1781/t2/2x/3b5f323c-d1cc-4c8c-b063-5afde753018e",
# 									"videoClips": [],
# 									"synopsis": "외모 따지지 않는 '개념녀'?\n아니, 나 완전 '얼빠'야!\n\n신입생 시절, 남자의 외모를 따지지 않는 \n개념녀라고 떠들었던 주인공 바니! \n그러나 첫 남자친구에게 '쉬운 여자'로 낙인되며\n신입생 바니의 첫 연애는 쓰게 막을 내린다.\n\n그리고 드디어 인정한 바니 자신의 ‘얼빠 속성’!\n\n‘잘생긴 남자가 좋다’는 사실을 외쳐댄 지 얼마 후, \n웬일인지 잘생긴 남자들이 자꾸만 꼬인다?\n  \n연애에 있어서는 자존감이 낮은 평범한 21살, \n그런 바니에게 호감을 표현하는 5명의 미남자!\n\n누구나 흑역사일 수밖에 없는 20대 초반의 연애, \n바니는 자신을 진심으로 사랑해주는 좋은 사람과 \n행복한 연애를 꾸릴 수 있을까?",
# 									"featuredCharacterAnimation": "https://kr-a.kakaopagecdn.com/P/C/1781/c1a/3b5f323c-d1cc-4c8c-b063-5afde753018e",
# 									"catchphraseThreeLines": "흑역사 첫 연애 후\n자꾸 남자들이 꼬인다!\n누가 똥차 누가 벤츠?",
# 									"badges": [
# 										{
# 											"title": "new",
# 											"type": "NEW",
# 											"imageUrl": "https://kr-a.kakaopagecdn.com/P/Z/2020-07-08/2x/e1c95b00-f38e-4874-9727-05d991ccd39f",
# 											"expiredDateTime": "2021-09-26T15:00:00Z"
# 										}
# 									],
# 									"featuredCharacterAnimationFirstFrame": "https://kr-a.kakaopagecdn.com/P/C/1781/c1a/2x/3b5f323c-d1cc-4c8c-b063-5afde753018e_f~os",
# 									"lastEpisodeSerialStartDateTime": "2021-10-03T15:00:00Z",
# 									"lastEpisodePublicationDateTime": "2021-08-29T13:00:28Z",
# 									"decorationImage": "https://kr-a.kakaopagecdn.com/P/C/1781/d/2x/3b5f323c-d1cc-4c8c-b063-5afde753018e",
# 									"lookThroughImage": "https://kr-a.kakaopagecdn.com/P/C/1781/lt/2x/3b5f323c-d1cc-4c8c-b063-5afde753018e",
# 									"adult": false,
# 									"webtoonType": "general",
# 									"authors": [
# 										{
# 											"name": "니은",
# 											"type": "AUTHOR",
# 											"order": 1
# 										},
# 										{
# 											"name": "니은",
# 											"type": "ILLUSTRATOR",
# 											"order": 2
# 										},
# 										{
# 											"name": "카카오웹툰 스튜디오",
# 											"type": "PUBLISHER",
# 											"order": 3
# 										}
# 									],
# 									"status": "SELLING"
# 								},
# 								"additional": {
# 									"new": false,
# 									"rest": false,
# 									"anchor": true,
# 									"labelBackgroundColor": "#4095FF",
# 									"mediaType": "clip",
# 									"label": "AI 추천",
# 									"up": true,
# 									"adult": false
# 								}
# 							},
# 							{
# 								"id": "60e413655c967c09c5ad247b",
# 								"key": "612d8bc048fc245bde93761a-60e413655c967c09c5ad247b",
# 								"content": {
# 									"lookThroughImages": [
# 										"https://kr-a.kakaopagecdn.com/P/C/1933/lt/2x/fe98d437-b49f-443d-ae33-5b7104749d36_000",
# 										"https://kr-a.kakaopagecdn.com/P/C/1933/lt/2x/fe98d437-b49f-443d-ae33-5b7104749d36_001",
# 										"https://kr-a.kakaopagecdn.com/P/C/1933/lt/2x/fe98d437-b49f-443d-ae33-5b7104749d36_002",
# 										"https://kr-a.kakaopagecdn.com/P/C/1933/lt/2x/fe98d437-b49f-443d-ae33-5b7104749d36_003",
# 										"https://kr-a.kakaopagecdn.com/P/C/1933/lt/2x/fe98d437-b49f-443d-ae33-5b7104749d36_004",
# 										"https://kr-a.kakaopagecdn.com/P/C/1933/lt/2x/fe98d437-b49f-443d-ae33-5b7104749d36_005",
# 										"https://kr-a.kakaopagecdn.com/P/C/1933/lt/2x/fe98d437-b49f-443d-ae33-5b7104749d36_006",
# 										"https://kr-a.kakaopagecdn.com/P/C/1933/lt/2x/fe98d437-b49f-443d-ae33-5b7104749d36_007",
# 										"https://kr-a.kakaopagecdn.com/P/C/1933/lt/2x/fe98d437-b49f-443d-ae33-5b7104749d36_008",
# 										"https://kr-a.kakaopagecdn.com/P/C/1933/lt/2x/fe98d437-b49f-443d-ae33-5b7104749d36_009"
# 									],
# 									"catchphraseTwoLines": "스무 살의 첫사랑, 스물아홉의 재회.\n그 때와 다를 수 있을까?",
# 									"backgroundImage": "https://kr-a.kakaopagecdn.com/P/C/1933/bg/2x/fe98d437-b49f-443d-ae33-5b7104749d36",
# 									"channel": "one",
# 									"completedDateTime": null,
# 									"title": "사귄 건 아닌데",
# 									"titleImageAHeight": 128,
# 									"seoKeywords": [
# 										"#설레는",
# 										"#가슴 먹먹한",
# 										"#로맨스",
# 										"#연애물"
# 									],
# 									"anchorClip": {
# 										"type": "LOOP",
# 										"clipUrl": "https://kr-a.kakaopagecdn.com/P/C/1933/aclip/4d6cfd8c-bd12-4d0a-a356-fe6f71177dce",
# 										"clipFirstFrame": "https://kr-a.kakaopagecdn.com/P/C/1933/aclip/2x/4d6cfd8c-bd12-4d0a-a356-fe6f71177dce_f~os",
# 										"clipLastFrame": "https://kr-a.kakaopagecdn.com/P/C/1933/aclip/2x/4d6cfd8c-bd12-4d0a-a356-fe6f71177dce_f~os"
# 									},
# 									"ageLimit": 0,
# 									"ipPromotionVideo": {
# 										"title": "사귄 건 아닌데",
# 										"subtitle": "스무 살의 첫사랑을 다시 만났다",
# 										"verticalVideo": "https://kr-a.kakaopagecdn.com/P/C/1933/ip1/81808492-0866-4c94-929a-8cdb02e12ee1",
# 										"horizontalVideo": "https://kr-a.kakaopagecdn.com/P/C/1933/ip2/eb6e5198-1c3f-4960-9b5e-fe35a20c3483"
# 									},
# 									"newContent": false,
# 									"serialRestartDateTime": null,
# 									"featuredCharacterImageA": "https://kr-a.kakaopagecdn.com/P/C/1933/c1/2x/fe98d437-b49f-443d-ae33-5b7104749d36",
# 									"serialStartDateTime": "2020-03-30T00:00:00Z",
# 									"id": 1933,
# 									"featuredCharacterAnimationLastFrame": "https://kr-a.kakaopagecdn.com/P/C/1933/c1a/2x/fe98d437-b49f-443d-ae33-5b7104749d36_l~os",
# 									"featuredCharacterImageB": "https://kr-a.kakaopagecdn.com/P/C/1933/c2/2x/fe98d437-b49f-443d-ae33-5b7104749d36",
# 									"seoId": "사귄-건-아닌데",
# 									"rest": false,
# 									"backgroundColor": "#646487",
# 									"upContent": true,
# 									"titleImageA": "https://kr-a.kakaopagecdn.com/P/C/1933/t1/2x/fe98d437-b49f-443d-ae33-5b7104749d36",
# 									"titleImageB": "https://kr-a.kakaopagecdn.com/P/C/1933/t2/2x/fe98d437-b49f-443d-ae33-5b7104749d36",
# 									"videoClips": [],
# 									"synopsis": "스물아홉 살, 서른을 목전에 둔 나이. \n고수아는 그 나이가 괜히 심란하다. \n\n고향을 떠나 서울에서 일을 하고 있지만,\n미래를 생각하면 고민이 많아진다. \n이곳에서의 삶에 대한 확신이 없기에. \n\n그러던 중 대학 시절에 짝사랑했던 후범과 재회하게 된다.\n9년 만의 재회에 다시 살아나는 그때의 감정.\n과거에 상처받았던 후범에 대한 마음을 봉합해 나가며 \n어린 시절에는 몰랐던 후범에 대해서 알아가게 된다. \n\n수아에게 다가온 또 다른 남자, 상사 기초롱.\n속 깊은 어른의 다정함을 보여주는 그가\n당황스러우면서도 마음 한쪽에선 호감이 싹 튼다. \n\n고민이 깊어진 스물아홉 살 수아가\n자신의 마음을 찾아가는 이야기.",
# 									"featuredCharacterAnimation": "https://kr-a.kakaopagecdn.com/P/C/1933/c1a/fe98d437-b49f-443d-ae33-5b7104749d36",
# 									"catchphraseThreeLines": "스무 살의 첫사랑을\n스물아홉에\n다시 만났다",
# 									"badges": [],
# 									"featuredCharacterAnimationFirstFrame": "https://kr-a.kakaopagecdn.com/P/C/1933/c1a/2x/fe98d437-b49f-443d-ae33-5b7104749d36_f~os",
# 									"lastEpisodeSerialStartDateTime": "2021-10-03T15:00:00Z",
# 									"lastEpisodePublicationDateTime": "2021-08-29T13:00:28Z",
# 									"decorationImage": "https://kr-a.kakaopagecdn.com/P/C/1933/d/2x/e9c80f47-07c7-45da-b131-f58c9152f87d",
# 									"lookThroughImage": "https://kr-a.kakaopagecdn.com/P/C/1933/lt/2x/fe98d437-b49f-443d-ae33-5b7104749d36",
# 									"adult": false,
# 									"webtoonType": "general",
# 									"authors": [
# 										{
# 											"name": "민홍",
# 											"type": "AUTHOR",
# 											"order": 1
# 										},
# 										{
# 											"name": "민홍",
# 											"type": "ILLUSTRATOR",
# 											"order": 2
# 										},
# 										{
# 											"name": "카카오웹툰 스튜디오",
# 											"type": "PUBLISHER",
# 											"order": 3
# 										}
# 									],
# 									"status": "SELLING"
# 								},
# 								"additional": {
# 									"new": false,
# 									"rest": false,
# 									"anchor": false,
# 									"labelBackgroundColor": "#4095FF",
# 									"mediaType": "image",
# 									"label": "AI 추천",
# 									"up": true,
# 									"adult": false
# 								}
# 							},
# 							{
# 								"id": "60e413675c967c09c5ad24ea",
# 								"key": "612d8bc048fc245bde93761a-60e413675c967c09c5ad24ea",
# 								"content": {
# 									"lookThroughImages": [
# 										"https://kr-a.kakaopagecdn.com/P/C/2147/lt/2x/c917caf4-bf05-410f-aa46-de35b3c767f1_000",
# 										"https://kr-a.kakaopagecdn.com/P/C/2147/lt/2x/c917caf4-bf05-410f-aa46-de35b3c767f1_001",
# 										"https://kr-a.kakaopagecdn.com/P/C/2147/lt/2x/c917caf4-bf05-410f-aa46-de35b3c767f1_002",
# 										"https://kr-a.kakaopagecdn.com/P/C/2147/lt/2x/c917caf4-bf05-410f-aa46-de35b3c767f1_003",
# 										"https://kr-a.kakaopagecdn.com/P/C/2147/lt/2x/c917caf4-bf05-410f-aa46-de35b3c767f1_004",
# 										"https://kr-a.kakaopagecdn.com/P/C/2147/lt/2x/c917caf4-bf05-410f-aa46-de35b3c767f1_005",
# 										"https://kr-a.kakaopagecdn.com/P/C/2147/lt/2x/c917caf4-bf05-410f-aa46-de35b3c767f1_006",
# 										"https://kr-a.kakaopagecdn.com/P/C/2147/lt/2x/c917caf4-bf05-410f-aa46-de35b3c767f1_007",
# 										"https://kr-a.kakaopagecdn.com/P/C/2147/lt/2x/c917caf4-bf05-410f-aa46-de35b3c767f1_008",
# 										"https://kr-a.kakaopagecdn.com/P/C/2147/lt/2x/c917caf4-bf05-410f-aa46-de35b3c767f1_009"
# 									],
# 									"catchphraseTwoLines": "괴생물 섭취 후 신체 변이\n감당 못 하는 힘을 갖게 되는데",
# 									"backgroundImage": "https://kr-a.kakaopagecdn.com/P/C/2147/bg/2x/c917caf4-bf05-410f-aa46-de35b3c767f1",
# 									"channel": "one",
# 									"completedDateTime": null,
# 									"title": "액괴",
# 									"titleImageAHeight": 76,
# 									"seoKeywords": [
# 										"#역동적인",
# 										"#긴장감 있는",
# 										"#학원/판타지",
# 										"#배틀물"
# 									],
# 									"anchorClip": {
# 										"type": null,
# 										"clipUrl": null,
# 										"clipFirstFrame": null,
# 										"clipLastFrame": null
# 									},
# 									"ageLimit": 15,
# 									"ipPromotionVideo": null,
# 									"newContent": false,
# 									"serialRestartDateTime": null,
# 									"featuredCharacterImageA": "https://kr-a.kakaopagecdn.com/P/C/2147/c1/2x/c917caf4-bf05-410f-aa46-de35b3c767f1",
# 									"serialStartDateTime": "2021-06-21T00:00:00Z",
# 									"id": 2147,
# 									"featuredCharacterAnimationLastFrame": null,
# 									"featuredCharacterImageB": "https://kr-a.kakaopagecdn.com/P/C/2147/c2/2x/c917caf4-bf05-410f-aa46-de35b3c767f1",
# 									"seoId": "액괴",
# 									"rest": false,
# 									"backgroundColor": "#353635",
# 									"upContent": true,
# 									"titleImageA": "https://kr-a.kakaopagecdn.com/P/C/2147/t1/2x/c917caf4-bf05-410f-aa46-de35b3c767f1",
# 									"titleImageB": "https://kr-a.kakaopagecdn.com/P/C/2147/t2/2x/c917caf4-bf05-410f-aa46-de35b3c767f1",
# 									"videoClips": [],
# 									"synopsis": "일진들에게 수모를 당하며\n황색망사점균을 먹게 된 교내 왕따 수와 진오.\n그로 인해 신체에 변이가 일어나고\n황색망사점균(블롭)의 특징과 힘을 가지게 된다.\n\n여전히 학교 내에선\n무시 받거나 괴롭힘 당하는 두 명의 아이들은\n힘의 정체를 숨긴 채\n차근차근 교내 먹이사슬을 장악해 가지만\n하나 둘 나타나는 액괴의 흔적이 사회의 이슈가 되고,\n변이된 블롭의 실험체를 만든\n김수혁의 등장으로 싸움은 점점 커져 간다.",
# 									"featuredCharacterAnimation": null,
# 									"catchphraseThreeLines": "괴생물 섭취 후 \n나타난 신체 변이\n이 구역의 짱은 나야",
# 									"badges": [],
# 									"featuredCharacterAnimationFirstFrame": null,
# 									"lastEpisodeSerialStartDateTime": "2021-10-31T15:00:00Z",
# 									"lastEpisodePublicationDateTime": "2021-08-29T13:00:28Z",
# 									"decorationImage": null,
# 									"lookThroughImage": "https://kr-a.kakaopagecdn.com/P/C/2147/lt/2x/c917caf4-bf05-410f-aa46-de35b3c767f1",
# 									"adult": false,
# 									"webtoonType": "general",
# 									"authors": [
# 										{
# 											"name": "서강용",
# 											"type": "AUTHOR",
# 											"order": 1
# 										},
# 										{
# 											"name": "서강용",
# 											"type": "ILLUSTRATOR",
# 											"order": 2
# 										},
# 										{
# 											"name": "카카오웹툰 스튜디오",
# 											"type": "PUBLISHER",
# 											"order": 3
# 										}
# 									],
# 									"status": "SELLING"
# 								},
# 								"additional": {
# 									"new": false,
# 									"rest": false,
# 									"anchor": false,
# 									"labelBackgroundColor": "#4095FF",
# 									"mediaType": "image",
# 									"label": "AI 추천",
# 									"up": true,
# 									"adult": false
# 								}
# 							},
# 							{
# 								"id": "60e413675c967c09c5ad24e4",
# 								"key": "612d8bc048fc245bde93761a-60e413675c967c09c5ad24e4",
# 								"content": {
# 									"lookThroughImages": [
# 										"https://kr-a.kakaopagecdn.com/P/C/2143/lt/2x/c3d7f24f-70da-4c2c-8d93-c182fc1d2bc5_000",
# 										"https://kr-a.kakaopagecdn.com/P/C/2143/lt/2x/c3d7f24f-70da-4c2c-8d93-c182fc1d2bc5_001",
# 										"https://kr-a.kakaopagecdn.com/P/C/2143/lt/2x/c3d7f24f-70da-4c2c-8d93-c182fc1d2bc5_002",
# 										"https://kr-a.kakaopagecdn.com/P/C/2143/lt/2x/c3d7f24f-70da-4c2c-8d93-c182fc1d2bc5_003",
# 										"https://kr-a.kakaopagecdn.com/P/C/2143/lt/2x/c3d7f24f-70da-4c2c-8d93-c182fc1d2bc5_004",
# 										"https://kr-a.kakaopagecdn.com/P/C/2143/lt/2x/c3d7f24f-70da-4c2c-8d93-c182fc1d2bc5_005",
# 										"https://kr-a.kakaopagecdn.com/P/C/2143/lt/2x/c3d7f24f-70da-4c2c-8d93-c182fc1d2bc5_006",
# 										"https://kr-a.kakaopagecdn.com/P/C/2143/lt/2x/c3d7f24f-70da-4c2c-8d93-c182fc1d2bc5_007",
# 										"https://kr-a.kakaopagecdn.com/P/C/2143/lt/2x/c3d7f24f-70da-4c2c-8d93-c182fc1d2bc5_008",
# 										"https://kr-a.kakaopagecdn.com/P/C/2143/lt/2x/c3d7f24f-70da-4c2c-8d93-c182fc1d2bc5_009"
# 									],
# 									"catchphraseTwoLines": "책 속 폭군이 나를 죽일 거라고?\n그리고 다가오는 남자들!",
# 									"backgroundImage": "https://kr-a.kakaopagecdn.com/P/C/2143/bg/2x/c3d7f24f-70da-4c2c-8d93-c182fc1d2bc5",
# 									"channel": "one",
# 									"completedDateTime": null,
# 									"title": "그 책에 마음을 주지 마세요",
# 									"titleImageAHeight": 168,
# 									"seoKeywords": [
# 										"#긴장감 있는",
# 										"#설레는",
# 										"#로맨스 판타지",
# 										"#복수물"
# 									],
# 									"anchorClip": {
# 										"type": null,
# 										"clipUrl": null,
# 										"clipFirstFrame": null,
# 										"clipLastFrame": null
# 									},
# 									"ageLimit": 0,
# 									"ipPromotionVideo": null,
# 									"newContent": false,
# 									"serialRestartDateTime": null,
# 									"featuredCharacterImageA": "https://kr-a.kakaopagecdn.com/P/C/2143/c1/2x/aea98c17-0067-44d7-a7bc-fe27cd66867c",
# 									"serialStartDateTime": "2021-06-07T00:00:00Z",
# 									"id": 2143,
# 									"featuredCharacterAnimationLastFrame": null,
# 									"featuredCharacterImageB": "https://kr-a.kakaopagecdn.com/P/C/2143/c2/2x/82ebbba0-c395-4d75-bf22-0f34262735be",
# 									"seoId": "그-책에-마음을-주지-마세요",
# 									"rest": false,
# 									"backgroundColor": "#6f7b88",
# 									"upContent": true,
# 									"titleImageA": "https://kr-a.kakaopagecdn.com/P/C/2143/t1/2x/c3d7f24f-70da-4c2c-8d93-c182fc1d2bc5",
# 									"titleImageB": "https://kr-a.kakaopagecdn.com/P/C/2143/t2/2x/c3d7f24f-70da-4c2c-8d93-c182fc1d2bc5",
# 									"videoClips": [],
# 									"synopsis": "로맨스 피폐 소설 「루스벨라의 빛」\n엑스트라인 황제의 여덟 번째 황녀로\n환생에 새로운 삶을 꿈꾸던 아실리 로제,\n\n그런 그녀의 앞에 미래를 예지하는\n일기장이 나타나는데…….\n\n「너에게 난 어떤 의미인가?\n질문이 끝나자 황태자님이 예쁘게 웃더니, 날 죽였다.」\n\n피도 눈물도 없는 황태자에게 살해당할\n미래만을 예고하는 일기장.\n불행히도 아실리는 죽어도 죽어도\n다시 살아나 계속 살해당했다.\n\n반복되는 죽음 속에서\n천천히 미소를 잃고 변해가는 아실리.\n도무지 피할 길이 없는 죽음,\n이 미래를 피해 생존할 수 있을까?\n\n한데 어째서인지 메말라 갈수록 아실리 곁에는\n사랑을 갈구하는 남자들이 모여드는데…….\n\n“제가 오라버니에게 무엇을 줄 수 있는데요?”\n“이름을 불러 봐.”\n\n이 사랑은 모두가 진짜일까?\n\n“사랑합니다.\n당신을 갖고 싶은 욕심은 사랑이 아닙니까?”\n\n다가오는 남자들의 진심은?\n\n“웃기지 마. 내 삶은 내 거야.”",
# 									"featuredCharacterAnimation": null,
# 									"catchphraseThreeLines": "책 속 폭군이\n나를 죽일 거라고?\n다가오는 남자들!",
# 									"badges": [],
# 									"featuredCharacterAnimationFirstFrame": null,
# 									"lastEpisodeSerialStartDateTime": "2021-10-24T15:00:00Z",
# 									"lastEpisodePublicationDateTime": "2021-08-22T13:00:24Z",
# 									"decorationImage": null,
# 									"lookThroughImage": "https://kr-a.kakaopagecdn.com/P/C/2143/lt/2x/c3d7f24f-70da-4c2c-8d93-c182fc1d2bc5",
# 									"adult": false,
# 									"webtoonType": "general",
# 									"authors": [
# 										{
# 											"name": "문시현",
# 											"type": "AUTHOR",
# 											"order": 1
# 										},
# 										{
# 											"name": "임조조",
# 											"type": "ILLUSTRATOR",
# 											"order": 2
# 										},
# 										{
# 											"name": "카카오웹툰 스튜디오",
# 											"type": "PUBLISHER",
# 											"order": 3
# 										}
# 									],
# 									"status": "SELLING"
# 								},
# 								"additional": {
# 									"new": false,
# 									"rest": false,
# 									"anchor": false,
# 									"labelBackgroundColor": "#4095FF",
# 									"mediaType": "image",
# 									"label": "AI 추천",
# 									"up": true,
# 									"adult": false
# 								}
# 							},
# 							{
# 								"id": "60e413555c967c09c5ad21ea",
# 								"key": "612d8bc048fc245bde93761a-60e413555c967c09c5ad21ea",
# 								"content": {
# 									"lookThroughImages": [
# 										"https://kr-a.kakaopagecdn.com/P/C/198/lt/2x/2fe6663d-5bfe-4752-a758-675d933102df_000",
# 										"https://kr-a.kakaopagecdn.com/P/C/198/lt/2x/2fe6663d-5bfe-4752-a758-675d933102df_001",
# 										"https://kr-a.kakaopagecdn.com/P/C/198/lt/2x/2fe6663d-5bfe-4752-a758-675d933102df_002",
# 										"https://kr-a.kakaopagecdn.com/P/C/198/lt/2x/2fe6663d-5bfe-4752-a758-675d933102df_003",
# 										"https://kr-a.kakaopagecdn.com/P/C/198/lt/2x/2fe6663d-5bfe-4752-a758-675d933102df_004",
# 										"https://kr-a.kakaopagecdn.com/P/C/198/lt/2x/2fe6663d-5bfe-4752-a758-675d933102df_005",
# 										"https://kr-a.kakaopagecdn.com/P/C/198/lt/2x/2fe6663d-5bfe-4752-a758-675d933102df_006",
# 										"https://kr-a.kakaopagecdn.com/P/C/198/lt/2x/2fe6663d-5bfe-4752-a758-675d933102df_007",
# 										"https://kr-a.kakaopagecdn.com/P/C/198/lt/2x/2fe6663d-5bfe-4752-a758-675d933102df_008",
# 										"https://kr-a.kakaopagecdn.com/P/C/198/lt/2x/2fe6663d-5bfe-4752-a758-675d933102df_009"
# 									],
# 									"catchphraseTwoLines": "다이어트 할 때 가장 위험한 만화\n추억과 음식과 이야기들",
# 									"backgroundImage": "https://kr-a.kakaopagecdn.com/P/C/198/bg/2x/fecbc7f1-49c1-46be-9fe9-ca80c7284a77",
# 									"channel": "one",
# 									"completedDateTime": null,
# 									"title": "오무라이스 잼잼",
# 									"titleImageAHeight": 132,
# 									"seoKeywords": [
# 										"#공감되는",
# 										"#식욕을 자극하는",
# 										"#코믹/일상",
# 										"#지식정보"
# 									],
# 									"anchorClip": {
# 										"type": null,
# 										"clipUrl": null,
# 										"clipFirstFrame": null,
# 										"clipLastFrame": null
# 									},
# 									"ageLimit": 0,
# 									"ipPromotionVideo": null,
# 									"newContent": false,
# 									"serialRestartDateTime": null,
# 									"featuredCharacterImageA": "https://kr-a.kakaopagecdn.com/P/C/198/c1/2x/fecbc7f1-49c1-46be-9fe9-ca80c7284a77",
# 									"serialStartDateTime": "2010-04-19T00:00:00Z",
# 									"id": 198,
# 									"featuredCharacterAnimationLastFrame": "https://kr-a.kakaopagecdn.com/P/C/198/c1a/2x/fecbc7f1-49c1-46be-9fe9-ca80c7284a77_l~os",
# 									"featuredCharacterImageB": "https://kr-a.kakaopagecdn.com/P/C/198/c2/2x/fecbc7f1-49c1-46be-9fe9-ca80c7284a77",
# 									"seoId": "오무라이스-잼잼",
# 									"rest": false,
# 									"backgroundColor": "#f3ad27",
# 									"upContent": true,
# 									"titleImageA": "https://kr-a.kakaopagecdn.com/P/C/198/t1/2x/fecbc7f1-49c1-46be-9fe9-ca80c7284a77",
# 									"titleImageB": "https://kr-a.kakaopagecdn.com/P/C/198/t2/2x/fecbc7f1-49c1-46be-9fe9-ca80c7284a77",
# 									"videoClips": [],
# 									"synopsis": "'음식'과 '가족'의 이야기를 담은 에세이 만화.\n\n몇 개라도 먹을 수 있을 것 같은 '메추리알 조림',\n빙글빙글 돌아가는 '회전초밥',\n지구 반 바퀴 돌아 포르투갈에서 맛본 '에그타르트',\n매콤상콤하게 볶아 입맛 도는 '마라샹궈',\n짭짤한 밥도둑 '간장게장' 등\n\n우리가 사랑하는 모든 음식들에 얽힌\n흥미진진한 비화와 따스한 이야기가 펼쳐진다.\n\n엄마, 아빠, 딸, 그리고 아들로 구성된\n작가의 가족이 전하는 음식의 알찬 정보!\n\n몸과 정신의 영양까지 챙기는 건강한 작품, 지금 시작됩니다!",
# 									"featuredCharacterAnimation": "https://kr-a.kakaopagecdn.com/P/C/198/c1a/fecbc7f1-49c1-46be-9fe9-ca80c7284a77",
# 									"catchphraseThreeLines": "다이어트 할 때\n가장 위험한 만화\n추억과 음식과 이야기들",
# 									"badges": [],
# 									"featuredCharacterAnimationFirstFrame": "https://kr-a.kakaopagecdn.com/P/C/198/c1a/2x/fecbc7f1-49c1-46be-9fe9-ca80c7284a77_f~os",
# 									"lastEpisodeSerialStartDateTime": "2021-10-03T15:00:00Z",
# 									"lastEpisodePublicationDateTime": "2021-08-22T13:00:25Z",
# 									"decorationImage": "https://kr-a.kakaopagecdn.com/P/C/198/d/2x/fecbc7f1-49c1-46be-9fe9-ca80c7284a77",
# 									"lookThroughImage": "https://kr-a.kakaopagecdn.com/P/C/198/lt/2x/2fe6663d-5bfe-4752-a758-675d933102df",
# 									"adult": false,
# 									"webtoonType": "general",
# 									"authors": [
# 										{
# 											"name": "조경규",
# 											"type": "AUTHOR",
# 											"order": 1
# 										},
# 										{
# 											"name": "조경규",
# 											"type": "ILLUSTRATOR",
# 											"order": 2
# 										},
# 										{
# 											"name": "카카오웹툰 스튜디오",
# 											"type": "PUBLISHER",
# 											"order": 3
# 										}
# 									],
# 									"status": "SELLING"
# 								},
# 								"additional": {
# 									"new": false,
# 									"rest": false,
# 									"anchor": false,
# 									"labelBackgroundColor": "#4095FF",
# 									"mediaType": "image",
# 									"label": "AI 추천",
# 									"up": true,
# 									"adult": false
# 								}
# 							},
# 							{
# 								"id": "60e413675c967c09c5ad24f5",
# 								"key": "612d8bc048fc245bde93761a-60e413675c967c09c5ad24f5",
# 								"content": {
# 									"lookThroughImages": [
# 										"https://kr-a.kakaopagecdn.com/P/C/2306/lt/2x/24186843-8ca9-4a1d-af95-fc4310c05c7a_000",
# 										"https://kr-a.kakaopagecdn.com/P/C/2306/lt/2x/24186843-8ca9-4a1d-af95-fc4310c05c7a_001",
# 										"https://kr-a.kakaopagecdn.com/P/C/2306/lt/2x/24186843-8ca9-4a1d-af95-fc4310c05c7a_002",
# 										"https://kr-a.kakaopagecdn.com/P/C/2306/lt/2x/24186843-8ca9-4a1d-af95-fc4310c05c7a_003",
# 										"https://kr-a.kakaopagecdn.com/P/C/2306/lt/2x/24186843-8ca9-4a1d-af95-fc4310c05c7a_004",
# 										"https://kr-a.kakaopagecdn.com/P/C/2306/lt/2x/24186843-8ca9-4a1d-af95-fc4310c05c7a_005",
# 										"https://kr-a.kakaopagecdn.com/P/C/2306/lt/2x/24186843-8ca9-4a1d-af95-fc4310c05c7a_006",
# 										"https://kr-a.kakaopagecdn.com/P/C/2306/lt/2x/24186843-8ca9-4a1d-af95-fc4310c05c7a_007",
# 										"https://kr-a.kakaopagecdn.com/P/C/2306/lt/2x/24186843-8ca9-4a1d-af95-fc4310c05c7a_008",
# 										"https://kr-a.kakaopagecdn.com/P/C/2306/lt/2x/24186843-8ca9-4a1d-af95-fc4310c05c7a_009"
# 									],
# 									"catchphraseTwoLines": "독고 시리즈 중 가장 처절한\n이야기가 펼쳐진다.",
# 									"backgroundImage": "https://kr-a.kakaopagecdn.com/P/C/2306/bg/2x/24186843-8ca9-4a1d-af95-fc4310c05c7a",
# 									"channel": "one",
# 									"completedDateTime": null,
# 									"title": "독고3 [완전판]",
# 									"titleImageAHeight": 76,
# 									"seoKeywords": [
# 										"#처절한",
# 										"#몰입되는",
# 										"#액션/무협",
# 										"#조직/암흑가"
# 									],
# 									"anchorClip": {
# 										"type": null,
# 										"clipUrl": null,
# 										"clipFirstFrame": null,
# 										"clipLastFrame": null
# 									},
# 									"ageLimit": 15,
# 									"ipPromotionVideo": null,
# 									"newContent": false,
# 									"serialRestartDateTime": null,
# 									"featuredCharacterImageA": "https://kr-a.kakaopagecdn.com/P/C/2306/c1/2x/24186843-8ca9-4a1d-af95-fc4310c05c7a",
# 									"serialStartDateTime": "2016-04-30T23:16:00Z",
# 									"id": 2306,
# 									"featuredCharacterAnimationLastFrame": "https://kr-a.kakaopagecdn.com/P/C/2306/c1a/2x/d512171c-9c77-4d33-b3b9-1d14c75e331f_l~os",
# 									"featuredCharacterImageB": "https://kr-a.kakaopagecdn.com/P/C/2306/c2/2x/24186843-8ca9-4a1d-af95-fc4310c05c7a",
# 									"seoId": "독고3-완전판",
# 									"rest": false,
# 									"backgroundColor": "#1b1b1b",
# 									"upContent": true,
# 									"titleImageA": "https://kr-a.kakaopagecdn.com/P/C/2306/t1/2x/24186843-8ca9-4a1d-af95-fc4310c05c7a",
# 									"titleImageB": "https://kr-a.kakaopagecdn.com/P/C/2306/t2/2x/24186843-8ca9-4a1d-af95-fc4310c05c7a",
# 									"videoClips": [],
# 									"synopsis": "모든 일에 의욕을 잃고 표류하던 태진은 과거 당영고 씨름부 주장이었던 심상윤으로부터\n영입 제안을 받게 되고 결국 현실과 타협하고 주먹의 세계에 몸을 담게 된다.\n그리고 그 세계에 적응해나가면서 점차 나락으로 떨어짐을 느끼게 되는데...\n독고 시리즈 중 가장 처절한 이야기가 펼쳐진다.",
# 									"featuredCharacterAnimation": "https://kr-a.kakaopagecdn.com/P/C/2306/c1a/d512171c-9c77-4d33-b3b9-1d14c75e331f",
# 									"catchphraseThreeLines": "독고 시리즈 중\n가장 처절한\n이야기가 펼쳐진다.",
# 									"badges": [],
# 									"featuredCharacterAnimationFirstFrame": "https://kr-a.kakaopagecdn.com/P/C/2306/c1a/2x/d512171c-9c77-4d33-b3b9-1d14c75e331f_f~os",
# 									"lastEpisodeSerialStartDateTime": "2021-08-29T13:00:23Z",
# 									"lastEpisodePublicationDateTime": "2021-08-29T13:00:23Z",
# 									"decorationImage": null,
# 									"lookThroughImage": "https://kr-a.kakaopagecdn.com/P/C/2306/lt/2x/24186843-8ca9-4a1d-af95-fc4310c05c7a",
# 									"adult": false,
# 									"webtoonType": "general",
# 									"authors": [
# 										{
# 											"name": "민(meen)",
# 											"type": "AUTHOR",
# 											"order": 1
# 										},
# 										{
# 											"name": "백승훈",
# 											"type": "ILLUSTRATOR",
# 											"order": 2
# 										},
# 										{
# 											"name": "투유드림",
# 											"type": "PUBLISHER",
# 											"order": 3
# 										}
# 									],
# 									"status": "SELLING"
# 								},
# 								"additional": {
# 									"new": false,
# 									"rest": false,
# 									"anchor": false,
# 									"labelBackgroundColor": "#4095FF",
# 									"mediaType": "image",
# 									"label": "AI 추천",
# 									"up": true,
# 									"adult": false
# 								}
# 							},
# 							{
# 								"id": "60e413675c967c09c5ad24e8",
# 								"key": "612d8bc048fc245bde93761a-60e413675c967c09c5ad24e8",
# 								"content": {
# 									"lookThroughImages": [
# 										"https://kr-a.kakaopagecdn.com/P/C/2145/lt/2x/70b098f5-3bbc-4855-8ed7-e96d74b9313c_000",
# 										"https://kr-a.kakaopagecdn.com/P/C/2145/lt/2x/70b098f5-3bbc-4855-8ed7-e96d74b9313c_001",
# 										"https://kr-a.kakaopagecdn.com/P/C/2145/lt/2x/70b098f5-3bbc-4855-8ed7-e96d74b9313c_002",
# 										"https://kr-a.kakaopagecdn.com/P/C/2145/lt/2x/70b098f5-3bbc-4855-8ed7-e96d74b9313c_003",
# 										"https://kr-a.kakaopagecdn.com/P/C/2145/lt/2x/70b098f5-3bbc-4855-8ed7-e96d74b9313c_004",
# 										"https://kr-a.kakaopagecdn.com/P/C/2145/lt/2x/70b098f5-3bbc-4855-8ed7-e96d74b9313c_005",
# 										"https://kr-a.kakaopagecdn.com/P/C/2145/lt/2x/70b098f5-3bbc-4855-8ed7-e96d74b9313c_006",
# 										"https://kr-a.kakaopagecdn.com/P/C/2145/lt/2x/70b098f5-3bbc-4855-8ed7-e96d74b9313c_007",
# 										"https://kr-a.kakaopagecdn.com/P/C/2145/lt/2x/70b098f5-3bbc-4855-8ed7-e96d74b9313c_008",
# 										"https://kr-a.kakaopagecdn.com/P/C/2145/lt/2x/70b098f5-3bbc-4855-8ed7-e96d74b9313c_009"
# 									],
# 									"catchphraseTwoLines": "짝남을 위해 만든 쿠키가 살아있다!\n자기의 사명이 내 고백 성공이라고?",
# 									"backgroundImage": "https://kr-a.kakaopagecdn.com/P/C/2145/bg/2x/70b098f5-3bbc-4855-8ed7-e96d74b9313c",
# 									"channel": "one",
# 									"completedDateTime": null,
# 									"title": "사랑하면 디져~트",
# 									"titleImageAHeight": 120,
# 									"seoKeywords": [
# 										"#발랄한",
# 										"#설레는",
# 										"#로맨스",
# 										"#로맨틱코미디물"
# 									],
# 									"anchorClip": {
# 										"type": null,
# 										"clipUrl": null,
# 										"clipFirstFrame": null,
# 										"clipLastFrame": null
# 									},
# 									"ageLimit": 0,
# 									"ipPromotionVideo": null,
# 									"newContent": false,
# 									"serialRestartDateTime": null,
# 									"featuredCharacterImageA": "https://kr-a.kakaopagecdn.com/P/C/2145/c1/2x/70b098f5-3bbc-4855-8ed7-e96d74b9313c",
# 									"serialStartDateTime": "2021-06-14T00:00:00Z",
# 									"id": 2145,
# 									"featuredCharacterAnimationLastFrame": null,
# 									"featuredCharacterImageB": "https://kr-a.kakaopagecdn.com/P/C/2145/c2/2x/70b098f5-3bbc-4855-8ed7-e96d74b9313c",
# 									"seoId": "사랑하면-디져트",
# 									"rest": false,
# 									"backgroundColor": "#816e6a",
# 									"upContent": true,
# 									"titleImageA": "https://kr-a.kakaopagecdn.com/P/C/2145/t1/2x/70b098f5-3bbc-4855-8ed7-e96d74b9313c",
# 									"titleImageB": "https://kr-a.kakaopagecdn.com/P/C/2145/t2/2x/70b098f5-3bbc-4855-8ed7-e96d74b9313c",
# 									"videoClips": [],
# 									"synopsis": "짝사랑에게 직접 구운 과자와 함께\n고백하고 싶다는 로망이 있는 베이킹 똥손 시현.\n드디어 인생 처음으로 단 하나의 쿠키를 만들어냈다.\n\n어, 그런데 이걸론 고백 못 하겠다. 왜냐? 살아 움직이니까!\n\n시현이 만든 쿠키인간(?) 진저는\n시현의 고백을 돕겠다고 나서지만 하는 짓이 영 못 미덥다.\n인간으로 변신해 말썽이나 피우지 않으면 다행. 제발 가만히 있어줘!\n\n짝사랑의 고비는 진저뿐만이 아니다.\n결정적으로 짝사랑 상대인 하성이 과자를 싫어한다...\n\n엉망진창 험난한 세 사람의 사랑 이야기.\n사랑하면서 무사히 살아남아라!",
# 									"featuredCharacterAnimation": null,
# 									"catchphraseThreeLines": "짝남을 위한\n쿠키가 살아있다!\n미션 : 고백 성공",
# 									"badges": [],
# 									"featuredCharacterAnimationFirstFrame": null,
# 									"lastEpisodeSerialStartDateTime": "2021-10-17T15:00:00Z",
# 									"lastEpisodePublicationDateTime": "2021-08-29T13:00:25Z",
# 									"decorationImage": null,
# 									"lookThroughImage": "https://kr-a.kakaopagecdn.com/P/C/2145/lt/2x/70b098f5-3bbc-4855-8ed7-e96d74b9313c",
# 									"adult": false,
# 									"webtoonType": "general",
# 									"authors": [
# 										{
# 											"name": "참치캔",
# 											"type": "AUTHOR",
# 											"order": 1
# 										},
# 										{
# 											"name": "참치캔",
# 											"type": "ILLUSTRATOR",
# 											"order": 2
# 										},
# 										{
# 											"name": "카카오웹툰 스튜디오",
# 											"type": "PUBLISHER",
# 											"order": 3
# 										}
# 									],
# 									"status": "SELLING"
# 								},
# 								"additional": {
# 									"new": false,
# 									"rest": false,
# 									"anchor": false,
# 									"labelBackgroundColor": "#4095FF",
# 									"mediaType": "image",
# 									"label": "AI 추천",
# 									"up": true,
# 									"adult": false
# 								}
# 							},
# 							{
# 								"id": "60e413665c967c09c5ad2488",
# 								"key": "612d8bc048fc245bde93761a-60e413665c967c09c5ad2488",
# 								"content": {
# 									"lookThroughImages": [
# 										"https://kr-a.kakaopagecdn.com/P/C/1959/lt/2x/dd364b64-11d6-4139-8702-e25c0375467f_000",
# 										"https://kr-a.kakaopagecdn.com/P/C/1959/lt/2x/dd364b64-11d6-4139-8702-e25c0375467f_001",
# 										"https://kr-a.kakaopagecdn.com/P/C/1959/lt/2x/dd364b64-11d6-4139-8702-e25c0375467f_002",
# 										"https://kr-a.kakaopagecdn.com/P/C/1959/lt/2x/dd364b64-11d6-4139-8702-e25c0375467f_003",
# 										"https://kr-a.kakaopagecdn.com/P/C/1959/lt/2x/dd364b64-11d6-4139-8702-e25c0375467f_004",
# 										"https://kr-a.kakaopagecdn.com/P/C/1959/lt/2x/dd364b64-11d6-4139-8702-e25c0375467f_005",
# 										"https://kr-a.kakaopagecdn.com/P/C/1959/lt/2x/dd364b64-11d6-4139-8702-e25c0375467f_006",
# 										"https://kr-a.kakaopagecdn.com/P/C/1959/lt/2x/dd364b64-11d6-4139-8702-e25c0375467f_007",
# 										"https://kr-a.kakaopagecdn.com/P/C/1959/lt/2x/dd364b64-11d6-4139-8702-e25c0375467f_008",
# 										"https://kr-a.kakaopagecdn.com/P/C/1959/lt/2x/dd364b64-11d6-4139-8702-e25c0375467f_009"
# 									],
# 									"catchphraseTwoLines": "대학생 시영이와 외로운 뱀파이어의 \n심쿵 먹방 동거생활!",
# 									"backgroundImage": "https://kr-a.kakaopagecdn.com/P/C/1959/bg/2x/3948aa5a-eac2-4109-b9bf-32810315ca4e",
# 									"channel": "one",
# 									"completedDateTime": null,
# 									"title": "뱀파이어님의 대리식사",
# 									"titleImageAHeight": 128,
# 									"seoKeywords": [
# 										"#설레는",
# 										"#발랄한",
# 										"#로맨스",
# 										"#동거물"
# 									],
# 									"anchorClip": {
# 										"type": null,
# 										"clipUrl": null,
# 										"clipFirstFrame": null,
# 										"clipLastFrame": null
# 									},
# 									"ageLimit": 0,
# 									"ipPromotionVideo": null,
# 									"newContent": false,
# 									"serialRestartDateTime": null,
# 									"featuredCharacterImageA": "https://kr-a.kakaopagecdn.com/P/C/1959/c1/2x/3948aa5a-eac2-4109-b9bf-32810315ca4e",
# 									"serialStartDateTime": "2020-05-11T00:00:00Z",
# 									"id": 1959,
# 									"featuredCharacterAnimationLastFrame": "https://kr-a.kakaopagecdn.com/P/C/1959/c1a/2x/3948aa5a-eac2-4109-b9bf-32810315ca4e_l~os",
# 									"featuredCharacterImageB": "https://kr-a.kakaopagecdn.com/P/C/1959/c2/2x/3948aa5a-eac2-4109-b9bf-32810315ca4e",
# 									"seoId": "뱀파이어님의-대리식사",
# 									"rest": false,
# 									"backgroundColor": "#72685d",
# 									"upContent": true,
# 									"titleImageA": "https://kr-a.kakaopagecdn.com/P/C/1959/t1/2x/3948aa5a-eac2-4109-b9bf-32810315ca4e",
# 									"titleImageB": "https://kr-a.kakaopagecdn.com/P/C/1959/t2/2x/3948aa5a-eac2-4109-b9bf-32810315ca4e",
# 									"videoClips": [],
# 									"synopsis": "\"대신 먹어주기만 하면 되는 '입주 대리식사' 알바?!\"\n\n가난한 대학생 강시영은 입주 대리식사 알바 면접을 위해 \n서울 외곽의 저택을 찾아가고,\n\n어두운 방에서 김치찌개 먹는 면접을 보고 덜컥 채용되지만\n보름달이 뜬 어느 밤, 고용주 ‘피선호’의 정체를 알게 된다. \n\n사실 그는 200년간 자가격리 중인 자살하기 직전의 \n우울증 클라이맥스를 겪고 있는 뱀파이어! \n\n정체를 들킨 그는 최면을 걸어 기억을 지우려 했지만, \n알 수 없는 이유로 실패하고 100일 뒤 \n다시 기억을 지우는 조건으로 재계약을 한다. \n \n기억을 지우기까지 남은 100일. \n동거하며 먹고 마시고 보고!\n\n씁쓸한 인생에 찾아온 달콤한 먹부림 로맨스!",
# 									"featuredCharacterAnimation": "https://kr-a.kakaopagecdn.com/P/C/1959/c1a/3948aa5a-eac2-4109-b9bf-32810315ca4e",
# 									"catchphraseThreeLines": "대학생 시영이와\n외로운 뱀파이어의 \n심쿵 먹방 동거생활!",
# 									"badges": [],
# 									"featuredCharacterAnimationFirstFrame": "https://kr-a.kakaopagecdn.com/P/C/1959/c1a/2x/3948aa5a-eac2-4109-b9bf-32810315ca4e_f~os",
# 									"lastEpisodeSerialStartDateTime": "2021-10-10T15:00:00Z",
# 									"lastEpisodePublicationDateTime": "2021-08-29T13:00:26Z",
# 									"decorationImage": null,
# 									"lookThroughImage": "https://kr-a.kakaopagecdn.com/P/C/1959/lt/2x/dd364b64-11d6-4139-8702-e25c0375467f",
# 									"adult": false,
# 									"webtoonType": "general",
# 									"authors": [
# 										{
# 											"name": "멜리",
# 											"type": "AUTHOR",
# 											"order": 1
# 										},
# 										{
# 											"name": "웬즈데이",
# 											"type": "ILLUSTRATOR",
# 											"order": 2
# 										},
# 										{
# 											"name": "카카오웹툰 스튜디오",
# 											"type": "PUBLISHER",
# 											"order": 3
# 										}
# 									],
# 									"status": "SELLING"
# 								},
# 								"additional": {
# 									"new": false,
# 									"rest": false,
# 									"anchor": false,
# 									"labelBackgroundColor": "#4095FF",
# 									"mediaType": "image",
# 									"label": "AI 추천",
# 									"up": true,
# 									"adult": false
# 								}
# 							},
# 							{
# 								"id": "60ef983f8bf92235c31bfd58",
# 								"key": "612d8bc048fc245bde93761a-60ef983f8bf92235c31bfd58",
# 								"content": {
# 									"lookThroughImages": [
# 										"https://kr-a.kakaopagecdn.com/P/C/2148/lt/2x/5b210ed5-d083-4a0f-8b22-d9e2a58106b9_000",
# 										"https://kr-a.kakaopagecdn.com/P/C/2148/lt/2x/5b210ed5-d083-4a0f-8b22-d9e2a58106b9_001",
# 										"https://kr-a.kakaopagecdn.com/P/C/2148/lt/2x/5b210ed5-d083-4a0f-8b22-d9e2a58106b9_002",
# 										"https://kr-a.kakaopagecdn.com/P/C/2148/lt/2x/5b210ed5-d083-4a0f-8b22-d9e2a58106b9_003",
# 										"https://kr-a.kakaopagecdn.com/P/C/2148/lt/2x/5b210ed5-d083-4a0f-8b22-d9e2a58106b9_004",
# 										"https://kr-a.kakaopagecdn.com/P/C/2148/lt/2x/5b210ed5-d083-4a0f-8b22-d9e2a58106b9_005",
# 										"https://kr-a.kakaopagecdn.com/P/C/2148/lt/2x/5b210ed5-d083-4a0f-8b22-d9e2a58106b9_006",
# 										"https://kr-a.kakaopagecdn.com/P/C/2148/lt/2x/5b210ed5-d083-4a0f-8b22-d9e2a58106b9_007",
# 										"https://kr-a.kakaopagecdn.com/P/C/2148/lt/2x/5b210ed5-d083-4a0f-8b22-d9e2a58106b9_008",
# 										"https://kr-a.kakaopagecdn.com/P/C/2148/lt/2x/5b210ed5-d083-4a0f-8b22-d9e2a58106b9_009"
# 									],
# 									"catchphraseTwoLines": "네 명이 모이면\n한 명은 정상이 아니다.",
# 									"backgroundImage": "https://kr-a.kakaopagecdn.com/P/C/2148/bg/2x/e5c4f895-3337-4069-aac0-e5171a56159a",
# 									"channel": "one",
# 									"completedDateTime": null,
# 									"title": "기숙사(死)",
# 									"titleImageAHeight": 70,
# 									"seoKeywords": [
# 										"#몰입되는",
# 										"#긴장감 있는",
# 										"#공포/스릴러",
# 										"#범죄스릴러물"
# 									],
# 									"anchorClip": {
# 										"type": null,
# 										"clipUrl": null,
# 										"clipFirstFrame": null,
# 										"clipLastFrame": null
# 									},
# 									"ageLimit": 19,
# 									"ipPromotionVideo": null,
# 									"newContent": false,
# 									"serialRestartDateTime": null,
# 									"featuredCharacterImageA": "https://kr-a.kakaopagecdn.com/P/C/2148/c1/2x/ef5e6f76-f80a-4f49-a7b4-13afdf5efa87",
# 									"serialStartDateTime": "2021-06-28T00:00:00Z",
# 									"id": 2148,
# 									"featuredCharacterAnimationLastFrame": null,
# 									"featuredCharacterImageB": "https://kr-a.kakaopagecdn.com/P/C/2148/c2/2x/85537ac2-d365-4e30-85a5-f2022034eb9d",
# 									"seoId": "기숙사",
# 									"rest": false,
# 									"backgroundColor": "#110F0E",
# 									"upContent": true,
# 									"titleImageA": "https://kr-a.kakaopagecdn.com/P/C/2148/t1/2x/b84d4341-277c-4f77-ad2e-01ccaf3a2725",
# 									"titleImageB": "https://kr-a.kakaopagecdn.com/P/C/2148/t2/2x/d3764b04-0400-441f-9f13-461c8172262f",
# 									"videoClips": [],
# 									"synopsis": "\"사람이 네 명이 모이면 한 명은 정상이 아니다\"\n\n요리과가 있는 세이 미디어 고등학교로 2학기 편입을 한\n평범한 학생 김민제는 기숙사 4인실에 입사하게 된다.\n\n하지만 룸메이트들은 모두 하나같이 정상이 아니었고\n오히려 평범한 김민제를 이상한 사람 취급을 한다.\n\n다수에 의해 결정되는 비정상.\n\n김민제는 1학기 때 자신과 같은 일을 겪었던\n고병철과 함께 살인 계획을 짜며\n정말로 점점 정상이 아니게 되어가는데..",
# 									"featuredCharacterAnimation": null,
# 									"catchphraseThreeLines": "정상 vs 비정상\n네 명이 모이면\n한 명은 비정상!",
# 									"badges": [
# 										{
# 											"title": "19",
# 											"type": "AGE_LIMIT",
# 											"imageUrl": "https://kr-a.kakaopagecdn.com/P/Z/2020-07-08/2x/1e9ee794-7b7c-409d-b031-c9a786093c9c",
# 											"expiredDateTime": null
# 										}
# 									],
# 									"featuredCharacterAnimationFirstFrame": null,
# 									"lastEpisodeSerialStartDateTime": "2021-10-10T15:00:00Z",
# 									"lastEpisodePublicationDateTime": "2021-08-22T13:00:24Z",
# 									"decorationImage": null,
# 									"lookThroughImage": "https://kr-a.kakaopagecdn.com/P/C/2148/lt/2x/5b210ed5-d083-4a0f-8b22-d9e2a58106b9",
# 									"adult": true,
# 									"webtoonType": "general",
# 									"authors": [
# 										{
# 											"name": "이제환",
# 											"type": "AUTHOR",
# 											"order": 1
# 										},
# 										{
# 											"name": "나는나야",
# 											"type": "ILLUSTRATOR",
# 											"order": 2
# 										},
# 										{
# 											"name": "카카오웹툰 스튜디오",
# 											"type": "PUBLISHER",
# 											"order": 3
# 										}
# 									],
# 									"status": "SELLING"
# 								},
# 								"additional": {
# 									"new": false,
# 									"rest": false,
# 									"anchor": false,
# 									"labelBackgroundColor": "#4095FF",
# 									"mediaType": "image",
# 									"label": "AI 추천",
# 									"up": true,
# 									"adult": true
# 								}
# 							},
# 							{
# 								"id": "60e413635c967c09c5ad2408",
# 								"key": "612d8bc048fc245bde93761a-60e413635c967c09c5ad2408",
# 								"content": {
# 									"lookThroughImages": [
# 										"https://kr-a.kakaopagecdn.com/P/C/1621/lt/2x/26d772dd-3e9d-4a14-ac55-dd2f58caaf9b_000",
# 										"https://kr-a.kakaopagecdn.com/P/C/1621/lt/2x/26d772dd-3e9d-4a14-ac55-dd2f58caaf9b_001",
# 										"https://kr-a.kakaopagecdn.com/P/C/1621/lt/2x/26d772dd-3e9d-4a14-ac55-dd2f58caaf9b_002",
# 										"https://kr-a.kakaopagecdn.com/P/C/1621/lt/2x/26d772dd-3e9d-4a14-ac55-dd2f58caaf9b_003",
# 										"https://kr-a.kakaopagecdn.com/P/C/1621/lt/2x/26d772dd-3e9d-4a14-ac55-dd2f58caaf9b_004",
# 										"https://kr-a.kakaopagecdn.com/P/C/1621/lt/2x/26d772dd-3e9d-4a14-ac55-dd2f58caaf9b_005",
# 										"https://kr-a.kakaopagecdn.com/P/C/1621/lt/2x/26d772dd-3e9d-4a14-ac55-dd2f58caaf9b_006",
# 										"https://kr-a.kakaopagecdn.com/P/C/1621/lt/2x/26d772dd-3e9d-4a14-ac55-dd2f58caaf9b_007",
# 										"https://kr-a.kakaopagecdn.com/P/C/1621/lt/2x/26d772dd-3e9d-4a14-ac55-dd2f58caaf9b_008",
# 										"https://kr-a.kakaopagecdn.com/P/C/1621/lt/2x/26d772dd-3e9d-4a14-ac55-dd2f58caaf9b_009"
# 									],
# 									"catchphraseTwoLines": "엑소시스트가 되고자 하는\n소녀의 이야기",
# 									"backgroundImage": "https://kr-a.kakaopagecdn.com/P/C/1621/bg/2x/f5e4e434-c61c-4cbc-8755-def6357181b7",
# 									"channel": "one",
# 									"completedDateTime": null,
# 									"title": "그라티아",
# 									"titleImageAHeight": 68,
# 									"seoKeywords": [
# 										"#압도되는",
# 										"#역동적인",
# 										"#학원/판타지",
# 										"#배틀물"
# 									],
# 									"anchorClip": {
# 										"type": null,
# 										"clipUrl": null,
# 										"clipFirstFrame": null,
# 										"clipLastFrame": null
# 									},
# 									"ageLimit": 0,
# 									"ipPromotionVideo": null,
# 									"newContent": false,
# 									"serialRestartDateTime": null,
# 									"featuredCharacterImageA": "https://kr-a.kakaopagecdn.com/P/C/1621/c1/2x/f5e4e434-c61c-4cbc-8755-def6357181b7",
# 									"serialStartDateTime": "2019-01-28T00:00:00Z",
# 									"id": 1621,
# 									"featuredCharacterAnimationLastFrame": "https://kr-a.kakaopagecdn.com/P/C/1621/c1a/2x/f5e4e434-c61c-4cbc-8755-def6357181b7_l~os",
# 									"featuredCharacterImageB": "https://kr-a.kakaopagecdn.com/P/C/1621/c2/2x/f5e4e434-c61c-4cbc-8755-def6357181b7",
# 									"seoId": "그라티아",
# 									"rest": false,
# 									"backgroundColor": "#001d3a",
# 									"upContent": true,
# 									"titleImageA": "https://kr-a.kakaopagecdn.com/P/C/1621/t1/2x/f5e4e434-c61c-4cbc-8755-def6357181b7",
# 									"titleImageB": "https://kr-a.kakaopagecdn.com/P/C/1621/t2/2x/f5e4e434-c61c-4cbc-8755-def6357181b7",
# 									"videoClips": [],
# 									"synopsis": "예수가 창조했다고 알려진 무한한 힘을 지닌 '권능의 열쇠'!\n\n10년 전, 그것을 얻기 위해 나타난 \n대악마 사탄으로 인해 뉴욕이 붕괴하고,\n\n살아남은 유일한 생존자, 전설의 엑소시스트 진오기는\n악마에게 빼앗긴 권능의 열쇠를 찾아 전 세계를 돌아다닌다.\n\n열쇠의 흔적을 쫓아 서울에 도달한 진오기는 \n씩씩한 소녀 길가온을 만나고, \n\n반 년 전에 자살로 죽은 친구 귀신을 지키는 \n가온에게서 엑소시스트 가능성을 본다. \n\n진오기를 만난 후,\n친구를 지키지 못했다는 자책감을 지니고 있던 가온도 \n소중한 사람을 지키기 위해 엑소시스트가 되기로 결심한다.",
# 									"featuredCharacterAnimation": "https://kr-a.kakaopagecdn.com/P/C/1621/c1a/f5e4e434-c61c-4cbc-8755-def6357181b7",
# 									"catchphraseThreeLines": "엑소시스트가\n되고자 하는\n소녀의 이야기",
# 									"badges": [],
# 									"featuredCharacterAnimationFirstFrame": "https://kr-a.kakaopagecdn.com/P/C/1621/c1a/2x/f5e4e434-c61c-4cbc-8755-def6357181b7_f~os",
# 									"lastEpisodeSerialStartDateTime": "2021-09-19T15:00:00Z",
# 									"lastEpisodePublicationDateTime": "2021-08-29T13:00:27Z",
# 									"decorationImage": null,
# 									"lookThroughImage": "https://kr-a.kakaopagecdn.com/P/C/1621/lt/2x/26d772dd-3e9d-4a14-ac55-dd2f58caaf9b",
# 									"adult": false,
# 									"webtoonType": "general",
# 									"authors": [
# 										{
# 											"name": "상민",
# 											"type": "AUTHOR",
# 											"order": 1
# 										},
# 										{
# 											"name": "기현",
# 											"type": "ILLUSTRATOR",
# 											"order": 2
# 										},
# 										{
# 											"name": "카카오웹툰 스튜디오",
# 											"type": "PUBLISHER",
# 											"order": 3
# 										}
# 									],
# 									"status": "SELLING"
# 								},
# 								"additional": {
# 									"new": false,
# 									"rest": false,
# 									"anchor": false,
# 									"labelBackgroundColor": "#4095FF",
# 									"mediaType": "image",
# 									"label": "AI 추천",
# 									"up": true,
# 									"adult": false
# 								}
# 							},
# 							{
# 								"id": "60e413655c967c09c5ad2468",
# 								"key": "612d8bc048fc245bde93761a-60e413655c967c09c5ad2468",
# 								"content": {
# 									"lookThroughImages": [
# 										"https://kr-a.kakaopagecdn.com/P/C/1903/lt/2x/70a3be5f-e689-4b84-a332-42e73a14faab_000",
# 										"https://kr-a.kakaopagecdn.com/P/C/1903/lt/2x/70a3be5f-e689-4b84-a332-42e73a14faab_001",
# 										"https://kr-a.kakaopagecdn.com/P/C/1903/lt/2x/70a3be5f-e689-4b84-a332-42e73a14faab_002",
# 										"https://kr-a.kakaopagecdn.com/P/C/1903/lt/2x/70a3be5f-e689-4b84-a332-42e73a14faab_003",
# 										"https://kr-a.kakaopagecdn.com/P/C/1903/lt/2x/70a3be5f-e689-4b84-a332-42e73a14faab_004",
# 										"https://kr-a.kakaopagecdn.com/P/C/1903/lt/2x/70a3be5f-e689-4b84-a332-42e73a14faab_005",
# 										"https://kr-a.kakaopagecdn.com/P/C/1903/lt/2x/70a3be5f-e689-4b84-a332-42e73a14faab_006",
# 										"https://kr-a.kakaopagecdn.com/P/C/1903/lt/2x/70a3be5f-e689-4b84-a332-42e73a14faab_007",
# 										"https://kr-a.kakaopagecdn.com/P/C/1903/lt/2x/70a3be5f-e689-4b84-a332-42e73a14faab_008",
# 										"https://kr-a.kakaopagecdn.com/P/C/1903/lt/2x/70a3be5f-e689-4b84-a332-42e73a14faab_009"
# 									],
# 									"catchphraseTwoLines": "다소 쓰레기 같은 대학생 작가의\n일상 만화. 수학을 싫어합니다.",
# 									"backgroundImage": "https://kr-a.kakaopagecdn.com/P/C/1903/bg/2x/70a3be5f-e689-4b84-a332-42e73a14faab",
# 									"channel": "one",
# 									"completedDateTime": null,
# 									"title": "쓰레기 머학생",
# 									"titleImageAHeight": 128,
# 									"seoKeywords": [
# 										"#웃기는",
# 										"#염세적인",
# 										"#코믹/일상",
# 										"#에피소드물"
# 									],
# 									"anchorClip": {
# 										"type": null,
# 										"clipUrl": null,
# 										"clipFirstFrame": null,
# 										"clipLastFrame": null
# 									},
# 									"ageLimit": 0,
# 									"ipPromotionVideo": null,
# 									"newContent": false,
# 									"serialRestartDateTime": "2021-04-12T00:00:00Z",
# 									"featuredCharacterImageA": "https://kr-a.kakaopagecdn.com/P/C/1903/c1/2x/70a3be5f-e689-4b84-a332-42e73a14faab",
# 									"serialStartDateTime": "2020-03-02T00:00:00Z",
# 									"id": 1903,
# 									"featuredCharacterAnimationLastFrame": "https://kr-a.kakaopagecdn.com/P/C/1903/c1a/2x/36f8f921-0136-4125-8a95-017543befaff_l~os",
# 									"featuredCharacterImageB": "https://kr-a.kakaopagecdn.com/P/C/1903/c2/2x/70a3be5f-e689-4b84-a332-42e73a14faab",
# 									"seoId": "쓰레기-머학생",
# 									"rest": false,
# 									"backgroundColor": "#8c8887",
# 									"upContent": true,
# 									"titleImageA": "https://kr-a.kakaopagecdn.com/P/C/1903/t1/2x/70a3be5f-e689-4b84-a332-42e73a14faab",
# 									"titleImageB": "https://kr-a.kakaopagecdn.com/P/C/1903/t2/2x/70a3be5f-e689-4b84-a332-42e73a14faab",
# 									"videoClips": [],
# 									"synopsis": "\"나는 흔한 대학생, 수학을 아주 싫어하지\"\n\n학교 수업은 출튀.\nPC방에서 하루 종일 게임.\n\n전공이지만 수학을 가장 싫어하고\n나중엔 주식투자로 돈도 잃어보기까지.\n\n수레기 작가의 다소 쓰레기 같은 대학 생활,\n그리고 졸업 후의 일상 이야기!",
# ...
# 										"https://kr-a.kakaopagecdn.com/P/C/2029/lt/2x/4e6472c9-6d7f-44ee-b7ab-6673d5e1e3b9_006",
# 										"https://kr-a.kakaopagecdn.com/P/C/2029/lt/2x/4e6472c9-6d7f-44ee-b7ab-6673d5e1e3b9_007",
# 										"https://kr-a.kakaopagecdn.com/P/C/2029/lt/2x/4e6472c9-6d7f-44ee-b7ab-6673d5e1e3b9_008",
# 										"https://kr-a.kakaopagecdn.com/P/C/2029/lt/2x/4e6472c9-6d7f-44ee-b7ab-6673d5e1e3b9_009"
# 									],
# 									"catchphraseTwoLines": "왕따 규현을 구해줄 마지막 희망, \n일진 크라우드 펀딩 앱 ‘울타리’",
# 									"backgroundImage": "https://kr-a.kakaopagecdn.com/P/C/2029/bg/2x/2d6e9cd0-6921-4e6c-8071-de3920c4e8ad",
# 									"channel": "one",
# 									"completedDateTime": "2021-03-28T00:00:00Z",
# 									"title": "크라우드",
# 									"titleImageAHeight": 64,
# 									"seoKeywords": [
# 										"#역동적인",
# 										"#통쾌한",
# 										"#학원/판타지",
# 										"#복수물"
# 									],
# 									"anchorClip": {
# 										"type": null,
# 										"clipUrl": null,
# 										"clipFirstFrame": null,
# 										"clipLastFrame": null
# 									},
# 									"ageLimit": 15,
# 									"ipPromotionVideo": null,
# 									"newContent": false,
# 									"serialRestartDateTime": null,
# 									"featuredCharacterImageA": "https://kr-a.kakaopagecdn.com/P/C/2029/c1/2x/2d6e9cd0-6921-4e6c-8071-de3920c4e8ad",
# 									"serialStartDateTime": "2020-08-30T00:00:00Z",
# 									"id": 2029,
# 									"featuredCharacterAnimationLastFrame": "https://kr-a.kakaopagecdn.com/P/C/2029/c1a/2x/2d6e9cd0-6921-4e6c-8071-de3920c4e8ad_l~os",
# 									"featuredCharacterImageB": "https://kr-a.kakaopagecdn.com/P/C/2029/c2/2x/2d6e9cd0-6921-4e6c-8071-de3920c4e8ad",
# 									"seoId": "크라우드",
# 									"rest": false,
# 									"backgroundColor": "#43443e",
# 									"upContent": false,
# 									"titleImageA": "https://kr-a.kakaopagecdn.com/P/C/2029/t1/2x/2d6e9cd0-6921-4e6c-8071-de3920c4e8ad",
# 									"titleImageB": "https://kr-a.kakaopagecdn.com/P/C/2029/t2/2x/2d6e9cd0-6921-4e6c-8071-de3920c4e8ad",
# 									"videoClips": [],
# 									"synopsis": "\"세상엔 쓰레기 같은 일진만 있을 뿐이다.\"\n\n일진 펀딩 앱 ‘울타리’!\n펀딩 성공 시, 해결사 '펜서'가 일진을 쓰러트린다.\n\n이에 규현은 자신을 괴롭히던 일진들을 펀딩하고, \n펜서인 '인성'의 도움을 받아 일진을 쓰러트린다.\n\n하지만 울타리는 펜서의 정체를 알게 된 규현을 가만\n안 두고, 설상가상 복수를 다짐한 일진까지 나타나며 \n규현은 울타리와 일진 모두의 표적이 된다.\n\n이제 규현이 선택할 수 있는 것은 한 가지 뿐. \n펜서가 되어 울타리의 추적을 피하고, \n일진들을 쓰러트리는 것이다.\n\n그렇게 규현은 인성에게 훈련을 받으며 \n점점 펜서의 길을 걷게 되는데...!",
# 									"featuredCharacterAnimation": "https://kr-a.kakaopagecdn.com/P/C/2029/c1a/2d6e9cd0-6921-4e6c-8071-de3920c4e8ad",
# 									"catchphraseThreeLines": "왕따의 마지막 희망\n크라우드 펀딩 앱으로\n일진을 사냥하라!",
# 									"badges": [],
# 									"featuredCharacterAnimationFirstFrame": "https://kr-a.kakaopagecdn.com/P/C/2029/c1a/2x/2d6e9cd0-6921-4e6c-8071-de3920c4e8ad_f~os",
# 									"lastEpisodeSerialStartDateTime": "2021-03-28T00:01:00Z",
# 									"lastEpisodePublicationDateTime": "2021-03-07T00:00:00Z",
# 									"decorationImage": null,
# 									"lookThroughImage": "https://kr-a.kakaopagecdn.com/P/C/2029/lt/2x/4e6472c9-6d7f-44ee-b7ab-6673d5e1e3b9",
# 									"adult": false,
# 									"webtoonType": "general",
# 									"authors": [
# 										{
# 											"name": "만두비",
# 											"type": "AUTHOR",
# 											"order": 1
# 										},
# 										{
# 											"name": "파크",
# 											"type": "ILLUSTRATOR",
# 											"order": 2
# 										},
# 										{
# 											"name": "카카오웹툰 스튜디오",
# 											"type": "PUBLISHER",
# 											"order": 3
# 										}
# 									],
# 									"status": "SELLING"
# 								},
# 								"additional": {
# 									"new": false,
# 									"rest": false,
# 									"anchor": false,
# 									"labelBackgroundColor": "#4095FF",
# 									"mediaType": "image",
# 									"label": "AI 추천",
# 									"up": false,
# 									"adult": false
# 								}
# 							},
# 							{
# 								"id": "60e413655c967c09c5ad246b",
# 								"key": "612d8bc048fc245bde93761c-60e413655c967c09c5ad246b",
# 								"content": {
# 									"lookThroughImages": [
# 										"https://kr-a.kakaopagecdn.com/P/C/1908/lt/2x/540a6557-3ad2-4b16-bcd5-1d25d0892c9b_000",
# 										"https://kr-a.kakaopagecdn.com/P/C/1908/lt/2x/540a6557-3ad2-4b16-bcd5-1d25d0892c9b_001",
# 										"https://kr-a.kakaopagecdn.com/P/C/1908/lt/2x/540a6557-3ad2-4b16-bcd5-1d25d0892c9b_002",
# 										"https://kr-a.kakaopagecdn.com/P/C/1908/lt/2x/540a6557-3ad2-4b16-bcd5-1d25d0892c9b_003",
# 										"https://kr-a.kakaopagecdn.com/P/C/1908/lt/2x/540a6557-3ad2-4b16-bcd5-1d25d0892c9b_004",
# 										"https://kr-a.kakaopagecdn.com/P/C/1908/lt/2x/540a6557-3ad2-4b16-bcd5-1d25d0892c9b_005",
# 										"https://kr-a.kakaopagecdn.com/P/C/1908/lt/2x/540a6557-3ad2-4b16-bcd5-1d25d0892c9b_006",
# 										"https://kr-a.kakaopagecdn.com/P/C/1908/lt/2x/540a6557-3ad2-4b16-bcd5-1d25d0892c9b_007",
# 										"https://kr-a.kakaopagecdn.com/P/C/1908/lt/2x/540a6557-3ad2-4b16-bcd5-1d25d0892c9b_008",
# 										"https://kr-a.kakaopagecdn.com/P/C/1908/lt/2x/540a6557-3ad2-4b16-bcd5-1d25d0892c9b_009"
# 									],
# 									"catchphraseTwoLines": "관종 패밀리의 막내지만\n그래도 평범하게 살고 싶어!",
# 									"backgroundImage": "https://kr-a.kakaopagecdn.com/P/C/1908/bg/2x/540a6557-3ad2-4b16-bcd5-1d25d0892c9b",
# 									"channel": "one",
# 									"completedDateTime": null,
# 									"title": "씨방것들",
# 									"titleImageAHeight": 68,
# 									"seoKeywords": [
# 										"#궁금하게 하는",
# 										"#발랄한",
# 										"#드라마",
# 										"#막장드라마"
# 									],
# 									"anchorClip": {
# 										"type": null,
# 										"clipUrl": null,
# 										"clipFirstFrame": null,
# 										"clipLastFrame": null
# 									},
# 									"ageLimit": 0,
# 									"ipPromotionVideo": null,
# 									"newContent": false,
# 									"serialRestartDateTime": "2021-01-10T00:00:00Z",
# 									"featuredCharacterImageA": "https://kr-a.kakaopagecdn.com/P/C/1908/c1/2x/540a6557-3ad2-4b16-bcd5-1d25d0892c9b",
# 									"serialStartDateTime": "2020-03-08T00:00:00Z",
# 									"id": 1908,
# 									"featuredCharacterAnimationLastFrame": "https://kr-a.kakaopagecdn.com/P/C/1908/c1a/2x/257d44c7-cb0b-48f3-8dfb-54cee4303524_l~os",
# 									"featuredCharacterImageB": "https://kr-a.kakaopagecdn.com/P/C/1908/c2/2x/540a6557-3ad2-4b16-bcd5-1d25d0892c9b",
# 									"seoId": "씨방것들",
# 									"rest": false,
# 									"backgroundColor": "#3f4647",
# 									"upContent": false,
# 									"titleImageA": "https://kr-a.kakaopagecdn.com/P/C/1908/t1/2x/540a6557-3ad2-4b16-bcd5-1d25d0892c9b",
# 									"titleImageB": "https://kr-a.kakaopagecdn.com/P/C/1908/t2/2x/540a6557-3ad2-4b16-bcd5-1d25d0892c9b",
# 									"videoClips": [],
# 									"synopsis": "웬만한 연예인보다 핫하다는\n대한민국 최고의 관종 가족 '방씨 일가'\n\n돈 많고 잘났지만 천박한 이 가족은 관심받기 위해\n어떤 막장 행동도 서슴지\u001c 않는다. \n\n불행히도 관종 가족 사이에서\n병적일 정도로 평범함을 추구하는\n막내딸 방은해의 인생 목표는 ‘공기처럼 살기’\n\n그러나 도움이 안 되는 가족들은 그들의 일상을 다룬 \n‘TV 리얼리티 프로그램’ 을 론칭, 방송 진출까지 꾀하는데...\n\n막내딸 방은해는 프로그램을 망치려다 오히려 \n대중의 관심을 받게 되고 설상가상 핫한 배우, 장휘민에게 첫눈에 반해버리고 만다!\n\n그 와중에 소꿉친구 남영원이 자신을 짝사랑했다는 걸 \n알게 되어 그야말로 혼란의 연속!\n\n공기같은 삶과 처음 느끼는 설렘, 자신을 이해해주는 존재.\n은해는 무엇을 지키고 무엇을 포기해야 할까?",
# 									"featuredCharacterAnimation": "https://kr-a.kakaopagecdn.com/P/C/1908/c1a/257d44c7-cb0b-48f3-8dfb-54cee4303524",
# 									"catchphraseThreeLines": "관종 패밀리의 막내, \n인생의 목표는\n'공기처럼 살기'",
# 									"badges": [],
# 									"featuredCharacterAnimationFirstFrame": "https://kr-a.kakaopagecdn.com/P/C/1908/c1a/2x/257d44c7-cb0b-48f3-8dfb-54cee4303524_f~os",
# 									"lastEpisodeSerialStartDateTime": "2021-07-25T00:01:00Z",
# 									"lastEpisodePublicationDateTime": "2021-06-13T00:00:00Z",
# 									"decorationImage": null,
# 									"lookThroughImage": "https://kr-a.kakaopagecdn.com/P/C/1908/lt/2x/540a6557-3ad2-4b16-bcd5-1d25d0892c9b",
# 									"adult": false,
# 									"webtoonType": "general",
# 									"authors": [
# 										{
# 											"name": "오청",
# 											"type": "AUTHOR",
# 											"order": 1
# 										},
# 										{
# 											"name": "오청",
# 											"type": "ILLUSTRATOR",
# 											"order": 2
# 										},
# 										{
# 											"name": "카카오웹툰 스튜디오",
# 											"type": "PUBLISHER",
# 											"order": 3
# 										}
# 									],
# 									"status": "SELLING"
# 								},
# 								"additional": {
# 									"new": false,
# 									"rest": false,
# 									"anchor": false,
# 									"labelBackgroundColor": "#4095FF",
# 									"mediaType": "image",
# 									"label": "AI 추천",
# 									"up": false,
# 									"adult": false
# 								}
# 							},
# 							{
# 								"id": "60e413665c967c09c5ad2490",
# 								"key": "612d8bc048fc245bde93761c-60e413665c967c09c5ad2490",
# 								"content": {
# 									"lookThroughImages": [
# 										"https://kr-a.kakaopagecdn.com/P/C/1982/lt/2x/165e3e84-77ed-498f-bee3-8391754e8290_000",
# 										"https://kr-a.kakaopagecdn.com/P/C/1982/lt/2x/165e3e84-77ed-498f-bee3-8391754e8290_001",
# 										"https://kr-a.kakaopagecdn.com/P/C/1982/lt/2x/165e3e84-77ed-498f-bee3-8391754e8290_002",
# 										"https://kr-a.kakaopagecdn.com/P/C/1982/lt/2x/165e3e84-77ed-498f-bee3-8391754e8290_003",
# 										"https://kr-a.kakaopagecdn.com/P/C/1982/lt/2x/165e3e84-77ed-498f-bee3-8391754e8290_004",
# 										"https://kr-a.kakaopagecdn.com/P/C/1982/lt/2x/165e3e84-77ed-498f-bee3-8391754e8290_005",
# 										"https://kr-a.kakaopagecdn.com/P/C/1982/lt/2x/165e3e84-77ed-498f-bee3-8391754e8290_006",
# 										"https://kr-a.kakaopagecdn.com/P/C/1982/lt/2x/165e3e84-77ed-498f-bee3-8391754e8290_007",
# 										"https://kr-a.kakaopagecdn.com/P/C/1982/lt/2x/165e3e84-77ed-498f-bee3-8391754e8290_008",
# 										"https://kr-a.kakaopagecdn.com/P/C/1982/lt/2x/165e3e84-77ed-498f-bee3-8391754e8290_009"
# 									],
# 									"catchphraseTwoLines": "어느날 우연히 주운 카메라에 \n미래가 찍힌다?!",
# 									"backgroundImage": "https://kr-a.kakaopagecdn.com/P/C/1982/bg/2x/165e3e84-77ed-498f-bee3-8391754e8290",
# 									"channel": "one",
# 									"completedDateTime": "2020-11-15T00:00:00Z",
# 									"title": "미래의 사진",
# 									"titleImageAHeight": 128,
# 									"seoKeywords": [
# 										"#궁금하게 하는",
# 										"#발랄한",
# 										"#로맨스",
# 										"#로맨틱코미디물"
# 									],
# 									"anchorClip": {
# 										"type": null,
# 										"clipUrl": null,
# 										"clipFirstFrame": null,
# 										"clipLastFrame": null
# 									},
# 									"ageLimit": 0,
# 									"ipPromotionVideo": null,
# 									"newContent": false,
# 									"serialRestartDateTime": null,
# 									"featuredCharacterImageA": "https://kr-a.kakaopagecdn.com/P/C/1982/c1/2x/165e3e84-77ed-498f-bee3-8391754e8290",
# 									"serialStartDateTime": "2020-06-14T00:00:00Z",
# 									"id": 1982,
# 									"featuredCharacterAnimationLastFrame": null,
# 									"featuredCharacterImageB": "https://kr-a.kakaopagecdn.com/P/C/1982/c2/2x/165e3e84-77ed-498f-bee3-8391754e8290",
# 									"seoId": "미래의-사진",
# 									"rest": false,
# 									"backgroundColor": "#bd7073",
# 									"upContent": false,
# 									"titleImageA": "https://kr-a.kakaopagecdn.com/P/C/1982/t1/2x/165e3e84-77ed-498f-bee3-8391754e8290",
# 									"titleImageB": "https://kr-a.kakaopagecdn.com/P/C/1982/t2/2x/165e3e84-77ed-498f-bee3-8391754e8290",
# 									"videoClips": [],
# 									"synopsis": "\"아무래도 이 카메라, 미래가 찍히는 것 같은데..?!\"\n\n사진 찍는 것을 좋아하는 평범한 여고생 한미래는\n우연히 버려진 폴라로이드 카메라의 비밀을 알게 된다.\n\n그리고 카메라에 찍힌 충격적인 장면!\n바로 미래가 짝사랑하는 반장, \n남주영이 머리를 맞은 채 쓰러져 있는 게 아닌가?\n\n카메라를 이용해 남주영을 구하기로 결심하지만 \n일진 황진일과 얽히게 되면서 범인으로 오해를 받지 않나, \n급기야 스토커 취급까지 받게 되는데!\n\n우여곡절 끝에 주영을 구하지만 미래는 뜻밖의 말을 듣는데. \n\n“미래야, 왜 나를 쫓아다니는거야?”\n\n아직 사건은 끝나지 않았다! \n설렘과 스릴이 공존하는 학원 미스터리 로맨스.",
# 									"featuredCharacterAnimation": null,
# 									"catchphraseThreeLines": "어느날 우연히 \n주운 카메라에 \n미래가 찍힌다?!",
# 									"badges": [],
# 									"featuredCharacterAnimationFirstFrame": null,
# 									"lastEpisodeSerialStartDateTime": "2020-11-15T00:00:00Z",
# 									"lastEpisodePublicationDateTime": "2020-11-15T00:00:00Z",
# 									"decorationImage": null,
# 									"lookThroughImage": "https://kr-a.kakaopagecdn.com/P/C/1982/lt/2x/165e3e84-77ed-498f-bee3-8391754e8290",
# 									"adult": false,
# 									"webtoonType": "general",
# 									"authors": [
# 										{
# 											"name": "낑깡",
# 											"type": "AUTHOR",
# 											"order": 1
# 										},
# 										{
# 											"name": "낑깡",
# 											"type": "ILLUSTRATOR",
# 											"order": 2
# 										},
# 										{
# 											"name": "카카오웹툰 스튜디오",
# 											"type": "PUBLISHER",
# 											"order": 3
# 										}
# 									],
# 									"status": "SELLING"
# 								},
# 								"additional": {
# 									"new": false,
# 									"rest": false,
# 									"anchor": false,
# 									"labelBackgroundColor": "#4095FF",
# 									"mediaType": "image",
# 									"label": "AI 추천",
# 									"up": false,
# 									"adult": false
# 								}
# 							}
# 						]
# 					}
# 				]
# 			}
# 		],
# 		"advertisements": [
# 			{
# 				"id": "602f15ec355bf7197951e295",
# 				"module": "AD_MOMENT",
# 				"placement": "ad_time_table_mon",
# 				"moment": true,
# 				"exceptionComponent": {
# 					"operationId": "99998",
# 					"backgroundColor": "#F3F3F3",
# 					"titleColor": "#333333",
# 					"subtitle": "채널 추가하고 새로운 소식 받기",
# 					"title": "세상에 없던 세상, 카카오웹툰",
# 					"thumbnailImage": "https://contents.kr.kakaowebtoon.com/P/Z/2020-07-08/2x/e3e00f92-98b3-48c9-82ef-93b865fc9552",
# 					"url": "https://pf.kakao.com/_FmQaxd"
# 				}
# 			},
# 			{
# 				"id": "602f15ec355bf7197951e296",
# 				"module": "AD_MOMENT",
# 				"placement": "ad_time_table_tue",
# 				"moment": true,
# 				"exceptionComponent": {
# 					"operationId": "99998",
# 					"backgroundColor": "#F3F3F3",
# 					"titleColor": "#333333",
# 					"subtitle": "채널 추가하고 새로운 소식 받기",
# 					"title": "세상에 없던 세상, 카카오웹툰",
# 					"thumbnailImage": "https://contents.kr.kakaowebtoon.com/P/Z/2020-07-08/2x/e3e00f92-98b3-48c9-82ef-93b865fc9552",
# 					"url": "https://pf.kakao.com/_FmQaxd"
# 				}
# 			},
# 			{
# 				"id": "602f15ec355bf7197951e297",
# 				"module": "AD_MOMENT",
# 				"placement": "ad_time_table_wed",
# 				"moment": true,
# 				"exceptionComponent": {
# 					"operationId": "99998",
# 					"backgroundColor": "#F3F3F3",
# 					"titleColor": "#333333",
# 					"subtitle": "채널 추가하고 새로운 소식 받기",
# 					"title": "세상에 없던 세상, 카카오웹툰",
# 					"thumbnailImage": "https://contents.kr.kakaowebtoon.com/P/Z/2020-07-08/2x/e3e00f92-98b3-48c9-82ef-93b865fc9552",
# 					"url": "https://pf.kakao.com/_FmQaxd"
# 				}
# 			},
# 			{
# 				"id": "602f15ec355bf7197951e298",
# 				"module": "AD_MOMENT",
# 				"placement": "ad_time_table_thu",
# 				"moment": true,
# 				"exceptionComponent": {
# 					"operationId": "99998",
# 					"backgroundColor": "#F3F3F3",
# 					"titleColor": "#333333",
# 					"subtitle": "채널 추가하고 새로운 소식 받기",
# 					"title": "세상에 없던 세상, 카카오웹툰",
# 					"thumbnailImage": "https://contents.kr.kakaowebtoon.com/P/Z/2020-07-08/2x/e3e00f92-98b3-48c9-82ef-93b865fc9552",
# 					"url": "https://pf.kakao.com/_FmQaxd"
# 				}
# 			},
# 			{
# 				"id": "602f15ec355bf7197951e299",
# 				"module": "AD_MOMENT",
# 				"placement": "ad_time_table_fri",
# 				"moment": true,
# 				"exceptionComponent": {
# 					"operationId": "99998",
# 					"backgroundColor": "#F3F3F3",
# 					"titleColor": "#333333",
# 					"subtitle": "채널 추가하고 새로운 소식 받기",
# 					"title": "세상에 없던 세상, 카카오웹툰",
# 					"thumbnailImage": "https://contents.kr.kakaowebtoon.com/P/Z/2020-07-08/2x/e3e00f92-98b3-48c9-82ef-93b865fc9552",
# 					"url": "https://pf.kakao.com/_FmQaxd"
# 				}
# 			},
# 			{
# 				"id": "602f15ec355bf7197951e29a",
# 				"module": "AD_MOMENT",
# 				"placement": "ad_time_table_sat",
# 				"moment": true,
# 				"exceptionComponent": {
# 					"operationId": "99998",
# 					"backgroundColor": "#F3F3F3",
# 					"titleColor": "#333333",
# 					"subtitle": "채널 추가하고 새로운 소식 받기",
# 					"title": "세상에 없던 세상, 카카오웹툰",
# 					"thumbnailImage": "https://contents.kr.kakaowebtoon.com/P/Z/2020-07-08/2x/e3e00f92-98b3-48c9-82ef-93b865fc9552",
# 					"url": "https://pf.kakao.com/_FmQaxd"
# 				}
# 			},
# 			{
# 				"id": "602f15ec355bf7197951e29b",
# 				"module": "AD_MOMENT",
# 				"placement": "ad_time_table_sun",
# 				"moment": true,
# 				"exceptionComponent": {
# 					"operationId": "99998",
# 					"backgroundColor": "#F3F3F3",
# 					"titleColor": "#333333",
# 					"subtitle": "채널 추가하고 새로운 소식 받기",
# 					"title": "세상에 없던 세상, 카카오웹툰",
# 					"thumbnailImage": "https://contents.kr.kakaowebtoon.com/P/Z/2020-07-08/2x/e3e00f92-98b3-48c9-82ef-93b865fc9552",
# 					"url": "https://pf.kakao.com/_FmQaxd"
# 				}
# 			}
# 		]
# 	}
# }

# %%
# 구조 정제

title = json_data['data']['sections'][0]['cardGroups'][0]['cards'][0]['content']['title']
keyword = json_data['data']['sections'][0]['cardGroups'][0]['cards'][0]['content']['seoKeywords']
synopsis = json_data['data']['sections'][0]['cardGroups'][0]['cards'][0]['content']['synopsis']
authors = json_data['data']['sections'][0]['cardGroups'][0]['cards'][0]['content']['authors']
featuredCharacterImageB = json_data['data']['sections'][0]['cardGroups'][0]['cards'][0]['content']['featuredCharacterImageB']

print(title)
print(keyword)
print(synopsis)
print(authors)
print(featuredCharacterImageB+'.png')
# Out:
# 바니와 오빠들
# ['#발랄한', '#설레는', '#로맨스', '#로맨틱코미디물']
# 외모 따지지 않는 '개념녀'?
# 아니, 나 완전 '얼빠'야!
#
# 신입생 시절, 남자의 외모를 따지지 않는
# 개념녀라고 떠들었던 주인공 바니!
# 그러나 첫 남자친구에게 '쉬운 여자'로 낙인되며
# 신입생 바니의 첫 연애는 쓰게 막을 내린다.
#
# 그리고 드디어 인정한 바니 자신의 ‘얼빠 속성’!
#
# ‘잘생긴 남자가 좋다’는 사실을 외쳐댄 지 얼마 후,
# 웬일인지 잘생긴 남자들이 자꾸만 꼬인다?
#
# 연애에 있어서는 자존감이 낮은 평범한 21살,
# 그런 바니에게 호감을 표현하는 5명의 미남자!
#
# 누구나 흑역사일 수밖에 없는 20대 초반의 연애,
# 바니는 자신을 진심으로 사랑해주는 좋은 사람과
# 행복한 연애를 꾸릴 수 있을까?
# [{'name': '니은', 'type': 'AUTHOR', 'order': 1}, {'name': '니은', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}]
# https://kr-a.kakaopagecdn.com/P/C/1781/c2/2x/51701624-4b03-405c-9db0-5a1be66409c0.png

# %%
x = 0
y = 0
z = 0

days = []
titles = []
keywords = []
synopsises = []
authorsl = []
main_image = []

while True:
  try:
    xs = json_data['data']['sections'][x]
    while True:
      try:
        ys = xs['cardGroups'][y]
        while True:
          try:
            day = xs['title']
            title = ys['cards'][z]['content']['title']
            keyword = ys['cards'][z]['content']['seoKeywords']
            synopsis = ys['cards'][z]['content']['synopsis']
            authors = ys['cards'][z]['content']['authors']
            images = ys['cards'][z]['content']['featuredCharacterImageB']

            days.append(day)
            titles.append(title)
            keywords.append(keyword)
            synopsises.append(synopsis)
            authorsl.append(authors)
            main_image.append(images)

            z += 1
          except:
            z = 0
            y += 1
            break
      except:
        z = 0
        y = 0
        x += 1
        break
  except:
    break

# %%
print(titles)
# Out:
# ['바니와 오빠들', '사귄 건 아닌데', '액괴', '그 책에 마음을 주지 마세요', '오무라이스 잼잼', '독고3 [완전판]', '사랑하면 디져~트', '뱀파이어님의 대리식사', '기숙사(死)', '그라티아', '쓰레기 머학생', '유부녀의 탄생', '강호표사', '이대로 멈출 순 없다', '환골탈태', '롱리브더킹', '니니툰즈', '흑우', '환율이 바뀌었나요?', '교수님을 빚는 중', '아싸가 알아버렸다', '집행자여', '천인의 신부', '현세이의 보이는 라디오', '일단 질러! 질렐루야', '무지개다리 파수꾼', '조류공포증', '타원을 그리
에게 빼앗긴 권능의 열쇠를 찾아 전 세계를 돌아다닌다.\n\n열쇠의 흔적을 쫓아 서울에 도달한 진오기는 \n씩씩한 소녀 길가온을 만나고, \n\n반 년 전에 자살로 죽은 친구 귀신을 지키는 \n가온에게서 엑소시스트 가능성을 본다. \n\n진오기를 만난 후,\n친구를 지키지 못했다는 자책감을 지니고 있던 가온도 \n소중한 사람을 지키기 위해 엑소시스트가 되기로 결심한다.", '"나는 흔한 대학생, 수학을 아주 싫어하지"\n\n학교 수업은 출튀.\nPC방에서 하루 종일 게임.\n\n전공이지만 수학을 가장 싫어하고\n나중엔 주식투자로 돈도 잃어보기까지.\n\n수레기 작가의 다소 쓰레기 같은 대학 생활,\n그리고 졸업 후의 일상 이야기!', '누구도 알려주지않은 결혼식 준비에 대한 리얼리티 카툰!', "정(正)과 사(邪)의 협객과 악당들이 힘을 겨루는 곳,\n'강호무림'(江湖武林)!\n\n조정의 부정부패와 무림인들의 패권 다툼 가운데\n백성들의 안전이 위협받는다.\n\n이에, 귀중품을 안전히 운반해 주고,\n신변을 경호하거나 재물을 지키는 등의 일을\n업으로 삼는 이들이 생겨났으니,\n병장기(金)를 들고 재물(票)을 지킨다 하여\n그들을 '표사'(鏢師)라 불렀다.\n\n'강호제일협'으로 친송받던 '노공수'로부터\n힘을 물려받은 '무영'이 강호의 정의를\n바로 세울 협객이 되기를 바라지만,\n무영은 언제나 돈 되는 의뢰만 밝히는\n속물근성 가득한 표사인데...\n\n그는 과연 강호무림의 사건들을 헤쳐나가며\n사부의 바람대로 '강호제일협'으로 거듭날 수 있을 것인가? ", '사상 최악의 막장 쓰레기 문제아 학교, \n정문여상에서 살아남기!\n\n자타공인 날라리 소연은 폭력 사건 주동자로 지목되어\n똥통 학교인 정문여상에 전학을 가게 된다.\n\n친어머니 집에 얹혀살게 된 소연은 \n자신을 둘러싼 모든 부당한 대우에 분노한다.\n\n설상가상으로 전학 첫 날, 왕따 폭행으로 전학 왔다는 \n‘오해’가 퍼지고, 상상도 못 할 만큼 저질인 양아치들과 \n보이지 않는 암묵적인 규칙이 소연을 압박해온다.\n\n민주 ...

# %%
print(authorsl)
# Out:
# [[{'name': '니은', 'type': 'AUTHOR', 'order': 1}, {'name': '니은', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': '민홍', 'type': 'AUTHOR', 'order': 1}, {'name': '민홍', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': '서강용', 'type': 'AUTHOR', 'order': 1}, {'name': '서강용', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': '문시현', 'type': 'AUTHOR', 'order': 1}, {'name': '임조조', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': '조경규', 'type': 'AUTHOR', 'order': 1}, {'name': '조경규', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': '민(meen)', 'type': 'AUTHOR', 'order': 1}, {'name': '백승훈', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '투유드림', 'type': 'PUBLISHER', 'order': 3}], [{'name': '참치캔', 'type': 'AUTHOR', 'order': 1}, {'name': '참치캔', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': '멜리', 'type': 'AUTHOR', 'order': 1}, {'name': '웬즈데이', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': '이제환', 'type': 'AUTHOR', 'order': 1}, {'name': '나는나야', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': '상민', 'type': 'AUTHOR', 'order': 1}, {'name': '기현', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': '수레기', 'type': 'AUTHOR', 'order': 1}, {'name': '수레기', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': '김환타', 'type': 'AUTHOR', 'order': 1}, {'name': '김환타', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': 'OZi', 'type': 'AUTHOR', 'order': 1}, {'name': 'OZi', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': '자룡', 'type': 'AUTHOR', 'order': 1}, {'name': '골왕', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': '마고(mago)', 'type': 'AUTHOR', 'order': 1}, {'name': '마고(mago)', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '마고(mago)', 'type': 'ORIGINAL_STORY', 'order': 3}, {'name': '거북이북스', 'type': 'PUBLISHER', 'order': 4}], [{'name': '버드나무숲', 'type': 'AUTHOR', 'order': 1}, {'name': '버드나무숲', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '서울미디어코믹스', 'type': 'PUBLISHER', 'order': 3}], [{'name': '니니즈', 'type': 'AUTHOR', 'order': 1}, {'name': '니니즈', 'type': 'PUBLISHER', 'order': 2}], [{'name': '유베테', 'type': 'AUTHOR', 'order': 1}, {'name': '늙슬', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': 'YB', 'type': 'AUTHOR', 'order': 1}, {'name': '쥐곰이', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': '서아', 'type': 'AUTHOR', 'order': 1}, {'name': '서아', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': '곰브', 'type': 'AUTHOR', 'order': 1}, {'name': '곰브', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': '종수', 'type': 'AUTHOR', 'order': 1}, {'name': '종수', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': '문솔', 'type': 'AUTHOR', 'order': 1}, {'name': '희명', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '학산', 'type': 'PUBLISHER', 'order': 3}], [{'name': '이제환', 'type': 'AUTHOR', 'order': 1}, {'name': '부족', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': 'yami', 'type': 'AUTHOR', 'order': 1}, {'name': 'yami', 'type': 'ILLUSTRATOR', 'order': 2}, {'name': '카카오웹툰 스튜디오', 'type': 'PUBLISHER', 'order': 3}], [{'name': '이서', 'type': 'AUTHOR', 'order': 1}, {'name': '이서', 'type ...

# %%
print(days)
# Out:
# ['월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '월', '화', '화', '화', '화', '화', '화', '화', '화', '화', '화', '화', '화', '화', '화', '화', '화', '화', '화', '화', '화', '화', '화', '화', '화', '화', '화', '수', '수', '수', '수', '수', '수', '수', '수', '수', '수', '수', '수', '수', '수', '수', '수', '수', '수', '수', '수', '수', '수', '수', '수', '수', '수', '수', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '목', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '금', '토', '토', '토', '토', '토', '토', '토', '토', '토', '토', '토', '토', '토', '토', '토', '토', '토', '토', '토', '토', '토', '토', '토', '토', '토', '일', '일', '일', '일', '일', '일', '일', '일', '일', '일', '일', '일', '일', '일', '일', '일', '일', '일', '일', '일', '일', '일']

# %%
authorsl[0][0]
# Out:
# {'name': '니은', 'type': 'AUTHOR', 'order': 1}

# %%
writers = [authorsl[i][0]['name'] for i in range(len(authorsl))]
illustrator = [authorsl[i][1]['name'] for i in range(len(authorsl))]

# %%
print(writers)
# Out:
# ['니은', '민홍', '서강용', '문시현', '조경규', '민(meen)', '참치캔', '멜리', '이제환', '상민', '수레기', '김환타', 'OZi', '자룡', '마고(mago)', '버드나무숲', '니니즈', '유베테', 'YB', '서아', '곰브', '종수', '문솔', '이제환', 'yami', '이서', '조눈', '섬멍', '정현수', '노경찬', '네온비', '향유 크리에이티브', '맥퀸스튜디오', '딩스', '공룡', '정이리이리', '붉은 발', '윤필', '강태경', '랑쓰', '글가애', '김종욱', '박하', '아람', '불만있냥', '니니즈', '장삥준', '금계수', '김다', '디디', '다노아', '건초', '이충호', '방자', '김용회', 'YOON', '마루', '김형민', '케이지콘', '짤태식', '고은', '강형규', '배혜수', '빛돌', '석빈', 'Axis', '나진수', '천계영', '보보군', '박경란', '만백', '니니즈', '키미하이', 'TB', '쑨', '일링스', '비아이', '박흥용', '기비', '강태진', '숭어', '한지혜', '용용', '정이나', '돌석', '마영신', '유리', '해소금', '노경찬', '우다', '김용회', '염라', '동남', '헤고', '문홍조', '백작', '도연', '송백', '니니즈', '강소소', '박세가', '수오', '김영현', '올챙구리', '김민소', '주명', '숭어', '체사', 'taibogi', '확천금', 'NASTY CAT', '효미', '아임', '김종훈', '김나임', '유영', '정영롱',
# %%
import pandas as pd

kakao = pd.DataFrame({'title':titles, 'day':days, 'genre':None, 'story':synopsises, 'platform':'카카오웹툰', 'Thumbnail':main_image})

# %%
kakao.head()
# Out:
#              title day genre  \
# 0          바니와 오빠들   월  None
# 1         사귄 건 아닌데   월  None
# 2               액괴   월  None
# 3  그 책에 마음을 주지 마세요   월  None
# 4         오무라이스 잼잼   월  None
#
#                                                story platform  \
# 0  외모 따지지 않는 '개념녀'?\n아니, 나 완전 '얼빠'야!\n\n신입생 시절, 남...    카카오웹툰
# 1  스물아홉 살, 서른을 목전에 둔 나이. \n고수아는 그 나이가 괜히 심란하다. \n...    카카오웹툰
# 2  일진들에게 수모를 당하며\n황색망사점균을 먹게 된 교내 왕따 수와 진오.\n그로 인...    카카오웹툰
# 3  로맨스 피폐 소설 「루스벨라의 빛」\n엑스트라인 황제의 여덟 번째 황녀로\n환생에 ...    카카오웹툰
# 4  '음식'과 '가족'의 이야기를 담은 에세이 만화.\n\n몇 개라도 먹을 수 있을 것...    카카오웹툰
#
#                                            Thumbnail
# 0  https://kr-a.kakaopagecdn.com/P/C/1781/c2/2x/5...
# 1  https://kr-a.kakaopagecdn.com/P/C/1933/c2/2x/f...
# 2  https://kr-a.kakaopagecdn.com/P/C/2147/c2/2x/c...
# 3  https://kr-a.kakaopagecdn.com/P/C/2143/c2/2x/8...
# 4  https://kr-a.kakaopagecdn.com/P/C/198/c2/2x/fe...

# %%
import re

def preprocess_sentence_kr(w):
  w = w.strip()
  w = re.sub(r"[^0-9가-힣?.!,¿]+", " ", w) # \n도 공백으로 대체해줌
  w = w.strip()
  return w

# %%
kakao['story'] = kakao['story'].apply(lambda x:preprocess_sentence_kr(x))

# %%
kakao.head()
# Out:
#              title day genre  \
# 0          바니와 오빠들   월  None
# 1         사귄 건 아닌데   월  None
# 2               액괴   월  None
# 3  그 책에 마음을 주지 마세요   월  None
# 4         오무라이스 잼잼   월  None
#
#                                                story platform  \
# 0  외모 따지지 않는 개념녀 ? 아니, 나 완전 얼빠 야! 신입생 시절, 남자의 외모를...    카카오웹툰
# 1  스물아홉 살, 서른을 목전에 둔 나이. 고수아는 그 나이가 괜히 심란하다. 고향을 ...    카카오웹툰
# 2  일진들에게 수모를 당하며 황색망사점균을 먹게 된 교내 왕따 수와 진오. 그로 인해 ...    카카오웹툰
# 3  로맨스 피폐 소설 루스벨라의 빛 엑스트라인 황제의 여덟 번째 황녀로 환생에 새로운 ...    카카오웹툰
# 4  음식 과 가족 의 이야기를 담은 에세이 만화. 몇 개라도 먹을 수 있을 것 같은 메...    카카오웹툰
#
#                                            Thumbnail
# 0  https://kr-a.kakaopagecdn.com/P/C/1781/c2/2x/5...
# 1  https://kr-a.kakaopagecdn.com/P/C/1933/c2/2x/f...
# 2  https://kr-a.kakaopagecdn.com/P/C/2147/c2/2x/c...
# 3  https://kr-a.kakaopagecdn.com/P/C/2143/c2/2x/8...
# 4  https://kr-a.kakaopagecdn.com/P/C/198/c2/2x/fe...

# %%
kakao.to_csv('kakao.csv', encoding='euc-kr')
